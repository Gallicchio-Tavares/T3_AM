# %% [markdown]
# <a id="top"></a>
# <div class="list-group" id="list-tab" role="tablist">
# <h1 class="list-group-item list-group-item-action active" data-toggle="list" style='background:#005097; border:0' role="tab" aria-controls="home"><center>APRENDIZADO DE MÁQUINA (GCC1932) - Trabalho 3</center></h1>
#
# - Nome completo: Bianca Gallicchio Tavares
# - [Link para vídeo](https://youtu.be/pR8AvE2IriM)

# %% [markdown]
# ## 0 - Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import tensorflow as tf
from tensorflow.keras import backend as K
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Conv1D, Dense, Dropout, Flatten, MaxPooling1D, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Configurações
plt.style.use('ggplot')
sns.set_palette("husl")
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 1 - Carregando o dataset

# %%
def load_and_analyze(data_path, feature_dict_path):
    """Carrega dados e realiza análise exploratória"""
    # Carregamento
    with open(data_path, 'rb') as f:
        X_train, y_train, X_val, y_val, X_test, y_test = pickle.load(f)
    
    feature_dict = pd.read_csv(feature_dict_path)
    
    # Análise de distribuição
    print("\nDistribuição dos Casos:")
    print(f"Total de casos (treino): {y_train.sum()}")
    print(f"Média semanal (treino): {y_train.mean():.2f}")
    print(f"Máximo em uma semana: {y_train.max()}")
    
    plt.figure(figsize=(10, 5))
    plt.hist(y_train, bins=50, alpha=0.7, label='Treino')
    plt.hist(y_val, bins=50, alpha=0.7, label='Validação')
    plt.hist(y_test, bins=50, alpha=0.7, label='Teste')
    plt.title('Distribuição dos Casos de Dengue')
    plt.legend()
    plt.show()
    
    return X_train, y_train, X_val, y_val, X_test, y_test, feature_dict

# %%
data_path = 'DATASETS/RJ_WEEKLY/dataset.pickle'
feature_dict_path = 'DATASETS/RJ_WEEKLY/feature_dictionary.csv'
X_train, y_train, X_val, y_val, X_test, y_test, feature_dict = load_and_analyze(data_path, feature_dict_path)
# Out:
# Distribuição dos Casos:
# Total de casos (treino): 47117
# Média semanal (treino): 0.20
# Máximo em uma semana: 337

# %% [markdown]
# ### Dicionário de Features

# %% [markdown]
# Este dicionário é gerado automaticamente durante a criação do dataset, baseado nas colunas do DataFrame final antes da conversão para NumPy.
#
# 1. **TEM_AVG**: Temperatura média diária (°C)
# 2. **TEM_MIN**: Temperatura mínima diária (°C)
# 3. **TEM_MAX**: Temperatura máxima diária (°C)
# 4. **RAIN**: Precipitação total diária (mm)
# 5. **RH_AVG**: Umidade relativa média do dia (%)
# 6. **RH_MIN**: Umidade relativa mínima do dia (%)
# 7. **RH_MAX**: Umidade relativa máxima do dia (%)
# 8. **IDEAL_TEMP**: Temperatura ideal para eclosão de ovos e amadurecimento do mosquito (°C)
# 9. **EXTREME_TEMP**: Temperatura nociva para o mosquito (°C)
# 10. **SIGNIFICANT_RAIN**: Chuva significativa capaz de criar novos criadouros (mm)
# 11. **EXTREME_RAIN**: Chuva extrema que remove ovos do ambiente (mm)
# 12. **TEMP_RANGE**: Amplitude térmica do dia (°C)
# 13. **WEEK_OF_YEAR**: Semana epidemiológica (1 a 52)
# 14. **TEM_AVG_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 15. **CASES_MM_7**: Número de casos reportados
# 16. **CASES_ACC_7**: Número de casos reportados
# 17. **RAIN_ACC_7**: Valor acumulado (soma ao longo do tempo)
# 18. **RAIN_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 19. **RH_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 20. **TEMP_RANGE_MM_7**: Amplitude térmica do dia (°C)
# 21. **TEM_AVG_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 22. **CASES_MM_14**: Número de casos reportados
# 23. **CASES_ACC_14**: Número de casos reportados
# 24. **RAIN_ACC_14**: Valor acumulado (soma ao longo do tempo)
# 25. **RAIN_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 26. **RH_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 27. **TEMP_RANGE_MM_14**: Amplitude térmica do dia (°C)
# 28. **TEM_AVG_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 29. **CASES_MM_21**: Número de casos reportados
# 30. **CASES_ACC_21**: Número de casos reportados
# 31. **RAIN_ACC_21**: Valor acumulado (soma ao longo do tempo)
# 32. **RAIN_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 33. **RH_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 34. **TEMP_RANGE_MM_21**: Amplitude térmica do dia (°C)
# 35. **TEM_AVG_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 36. **CASES_MM_28**: Número de casos reportados
# 37. **CASES_ACC_28**: Número de casos reportados
# 38. **RAIN_ACC_28**: Valor acumulado (soma ao longo do tempo)
# 39. **RAIN_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 40. **RH_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 41. **TEMP_RANGE_MM_28**: Amplitude térmica do dia (°C)
# 42. **CASES_LAG_1**: Número de casos reportados
# 43. **CASES_LAG_2**: Número de casos reportados
# 44. **CASES_LAG_3**: Número de casos reportados
# 45. **CASES_LAG_4**: Número de casos reportados
# 46. **CASES_LAG_5**: Número de casos reportados
# 47. **CASES_LAG_6**: Número de casos reportados

# %% [markdown]
# ## 2 - Análise Exploratória

# %%
# Carregando o dicionário de features para entender as variáveis
feature_dict = pd.read_csv('DATASETS/RJ_WEEKLY/feature_dictionary.csv')
print("\nDicionário de Variáveis:")
print(feature_dict)
# Out:
# Dicionário de Variáveis:
#     Index           Feature
# 0       0           TEM_AVG
# 1       1           TEM_MIN
# 2       2           TEM_MAX
# 3       3              RAIN
# 4       4            RH_AVG
# 5       5            RH_MIN
# 6       6            RH_MAX
# 7       7        CASES_MM_7
# 8       8       CASES_MM_14
# 9       9       CASES_MM_21
# 10     10       CASES_MM_28
# 11     11       CASES_ACC_7
# 12     12      CASES_ACC_14
# 13     13      CASES_ACC_21
# 14     14      CASES_ACC_28
# 15     15       CASES_LAG_1
# 16     16       CASES_LAG_2
# 17     17       CASES_LAG_3
# 18     18       CASES_LAG_4
# 19     19       CASES_LAG_5
# 20     20       CASES_LAG_6
# 21     21        IDEAL_TEMP
# 22     22      EXTREME_TEMP
# 23     23  SIGNIFICANT_RAIN
# 24     24      EXTREME_RAIN
# 25     25        TEMP_RANGE
# 26     26      WEEK_OF_YEAR
# 27     27      TEM_AVG_MM_7
# 28     28        RAIN_ACC_7
# 29     29         RAIN_MM_7
# 30     30           RH_MM_7
# 31     31   TEMP_RANGE_MM_7
# 32     32     TEM_AVG_MM_14
# 33     33       RAIN_ACC_14
# 34     34        RAIN_MM_14
# 35     35          RH_MM_14
# 36     36  TEMP_RANGE_MM_14
# 37     37     TEM_AVG_MM_21
# 38     38       RAIN_ACC_21
# 39     39        RAIN_MM_21
# 40     40          RH_MM_21
# 41     41  TEMP_RANGE_MM_21
# 42     42     TEM_AVG_MM_28
# 43     43       RAIN_ACC_28
# 44     44        RAIN_MM_28
# 45     45          RH_MM_28
# 46     46  TEMP_RANGE_MM_28

# %%
# Verificando a dimensionalidade dos dados
print("\nDimensionalidade dos dados:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Dimensionalidade dos dados:
# X_train shape: (235118, 47)
# y_train shape: (235118,)

# %% [markdown]
# O dataset é **altamente desbalanceado**, com a maioria das observações registrando **zero casos** de dengue.
# Essa característica é comum em contextos epidemiológicos onde a maioria dos dias/unidades não apresentam surtos.

# %%
# Estatísticas de distribuição de classes
n_total = len(y_train)
n_positive = np.sum(y_train > 0)
n_zero = n_total - n_positive
pct_positive = (n_positive / n_total) * 100

print(f"Total de amostras: {n_total}")
print(f"Com casos (>0): {n_positive} ({pct_positive:.2f}%)")
print(f"Sem casos (=0): {n_zero} ({100 - pct_positive:.2f}%)")
# Out:
# Total de amostras: 235118
# Com casos (>0): 7805 (3.32%)
# Sem casos (=0): 227313 (96.68%)

# %%
# Correlações com variáveis climáticas
cases_related_vars = [
    'CASES_MM_7', 'CASES_ACC_7', 'CASES_MM_14', 'CASES_ACC_14',
    'CASES_MM_21', 'CASES_ACC_21', 'CASES_MM_28', 'CASES_ACC_28',
    'CASES_LAG_1', 'CASES_LAG_2', 'CASES_LAG_3', 'CASES_LAG_4',
    'CASES_LAG_5', 'CASES_LAG_6'
]
climate_vars = [f for f in feature_dict['Feature'] if f not in cases_related_vars]

df_train_climate = pd.DataFrame(X_train, columns=feature_dict['Feature'])
df_train_climate = df_train_climate[climate_vars]
df_train_climate['Casos'] = y_train

corr_matrix_climate = df_train_climate.corr()

plt.figure(figsize=(12, 6))
corr_matrix_climate['Casos'].sort_values(ascending=False)[:-1].plot(kind='bar')
plt.title('Correlação entre Variáveis Climáticas e Casos de Dengue')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Mostrando as 10 variáveis climáticas mais correlacionadas
print("\nTop 10 variáveis CLIMÁTICAS mais correlacionadas com Casos de Dengue:")
print(corr_matrix_climate['Casos'].sort_values(ascending=False).head(11)[1:])  # Pula a correlação consigo mesmo

print("\nTop 10 variáveis CLIMÁTICAS mais negativamente correlacionadas com Casos de Dengue:")
print(corr_matrix_climate['Casos'].sort_values().head(10))
# Out:
# Top 10 variáveis CLIMÁTICAS mais correlacionadas com Casos de Dengue:
# Feature
# RAIN_ACC_21     0.032468
# RAIN_MM_21      0.032468
# RAIN_ACC_28     0.031881
# RAIN_MM_28      0.031881
# RAIN_MM_14      0.027074
# RAIN_ACC_14     0.027074
# RH_MM_7         0.018568
# RH_MM_14        0.016504
# RH_AVG          0.015392
# EXTREME_TEMP    0.014736
# Name: Casos, dtype: float64
#
# Top 10 variáveis CLIMÁTICAS mais negativamente correlacionadas com Casos de Dengue:
# Feature
# WEEK_OF_YEAR       -0.031065
# TEMP_RANGE_MM_7    -0.025737
# TEMP_RANGE_MM_14   -0.023960
# TEMP_RANGE         -0.017104
# TEM_MAX            -0.015629
# TEMP_RANGE_MM_21   -0.014926
# TEM_AVG            -0.003996
# TEMP_RANGE_MM_28   -0.003591
# SIGNIFICANT_RAIN   -0.002144
# TEM_MIN            -0.001036
# Name: Casos, dtype: float64

# %% [markdown]
# ## 3 - Classificação Binária

# %% [markdown]
# ### 3.1 Pré-processamento

# %%
# Transformando y em binário (1 = caso, 0 = sem caso)
y_train_bin = (y_train > 0).astype(int)
y_val_bin = (y_val > 0).astype(int)
y_test_bin = (y_test > 0).astype(int)

# %% [markdown]
# #### Criando janelas temporais

# %%
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(window_size, len(X)):
        X_seq.append(X[i-window_size:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

window_size = 14

X_train_seq, y_train_seq = create_sequences(X_train, y_train_bin, window_size)
X_val_seq, y_val_seq = create_sequences(X_val, y_val_bin, window_size)
X_test_seq, y_test_seq = create_sequences(X_test, y_test_bin, window_size)

# %% [markdown]
# #### Normalização

# %%
X_scaler = MinMaxScaler()

X_train_flat = X_train_seq.reshape(-1, X_train_seq.shape[2])
X_val_flat = X_val_seq.reshape(-1, X_val_seq.shape[2])
X_test_flat = X_test_seq.reshape(-1, X_test_seq.shape[2])

X_scaler.fit(X_train_flat)

X_train_norm = X_scaler.transform(X_train_flat).reshape(X_train_seq.shape)
X_val_norm = X_scaler.transform(X_val_flat).reshape(X_val_seq.shape)
X_test_norm = X_scaler.transform(X_test_flat).reshape(X_test_seq.shape)

# %% [markdown]
# ### 3.2 Modelo LSTM

# %%
lstm_model = Sequential([
    Input(shape=(window_size, X_train_norm.shape[2])),
    LSTM(64, return_sequences=False),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # Saída binária
])

lstm_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, verbose=1),
    ModelCheckpoint('melhor_lstm_classificacao.keras', save_best_only=True, monitor='val_loss')
]

# %%
history_lstm = lstm_model.fit(
    X_train_norm, y_train_seq,
    validation_data=(X_val_norm, y_val_seq),
    epochs=100,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - accuracy: 0.9678 - loss: 0.1361 - precision: 0.5383 - recall: 0.0817 - val_accuracy: 0.9662 - val_loss: 0.1173 - val_precision: 0.7159 - val_recall: 0.2800 - learning_rate: 0.0010
# Epoch 2/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9723 - loss: 0.0978 - precision: 0.6954 - recall: 0.2853 - val_accuracy: 0.9675 - val_loss: 0.1097 - val_precision: 0.7380 - val_recall: 0.3123 - learning_rate: 0.0010
# Epoch 3/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9730 - loss: 0.0918 - precision: 0.6991 - recall: 0.3203 - val_accuracy: 0.9677 - val_loss: 0.1093 - val_precision: 0.7463 - val_recall: 0.3107 - learning_rate: 0.0010
# Epoch 4/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.9732 - loss: 0.0890 - precision: 0.7076 - recall: 0.3225 - val_accuracy: 0.9678 - val_loss: 0.1125 - val_precision: 0.7654 - val_recall: 0.2980 - learning_rate: 0.0010
# Epoch 5/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9739 - loss: 0.0870 - precision: 0.7282 - recall: 0.3326 - val_accuracy: 0.9678 - val_loss: 0.1084 - val_precision: 0.7830 - val_recall: 0.2890 - learning_rate: 0.0010
# Epoch 6/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.9741 - loss: 0.0859 - precision: 0.7329 - recall: 0.3366 - val_accuracy: 0.9682 - val_loss: 0.1099 - val_precision: 0.7583 - val_recall: 0.3199 - learning_rate: 0.0010
# Epoch 7/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9739 - loss: 0.0853 - precision: 0.7240 - recall: 0.3403 - val_accuracy: 0.9680 - val_loss: 0.1060 - val_precision: 0.7711 - val_recall: 0.3034 - learning_rate: 0.0010
# Epoch 8/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9742 - loss: 0.0846 - precision: 0.7394 - recall: 0.3355 - val_accuracy: 0.9683 - val_loss: 0.1044 - val_precision: 0.7633 - val_recall: 0.3203 - learning_rate: 0.0010
# Epoch 9/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9742 - loss: 0.0840 - precision: 0.7368 - recall: 0.3380 - val_accuracy: 0.9680 - val_loss: 0.1050 - val_precision: 0.7827 - val_recall: 0.2937 - learning_rate: 0.0010
# Epoch 10/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9740 - loss: 0.0834 - precision: 0.7322 - recall: 0.3336 - val_accuracy: 0.9680 - val_loss: 0.1038 - val_precision: 0.7835 - val_recall: 0.2942 - learning_rate: 0.0010
# Epoch 11/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9742 - loss: 0.0827 - precision: 0.7401 - recall: 0.3362 - val_accuracy: 0.9682 - val_loss: 0.1027 - val_precision: 0.7748 - val_recall: 0.3058 - learning_rate: 0.0010
# Epoch 12/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9745 - loss: 0.0822 - precision: 0.7478 - recall: 0.3419 - val_accuracy: 0.9683 - val_loss: 0.1021 - val_precision: 0.7607 - val_recall: 0.3200 - learning_rate: 0.0010
# Epoch 13/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9743 - loss: 0.0818 - precision: 0.7391 - recall: 0.3414 - val_accuracy: 0.9680 - val_loss: 0.1046 - val_precision: 0.7792 - val_recall: 0.2965 - learning_rate: 0.0010
# Epoch 14/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9746 - loss: 0.0816 - precision: 0.7459 - recall: 0.3479 - val_accuracy: 0.9683 - val_loss: 0.1018 - val_precision: 0.7690 - val_recall: 0.3132 - learning_rate: 0.0010
# Epoch 15/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9745 - loss: 0.0809 - precision: 0.7443 - recall: 0.3446 - val_accuracy: 0.9681 - val_loss: 0.1020 - val_precision: 0.7785 - val_recall: 0.3018 - learning_rate: 0.0010
# Epoch 16/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9744 - loss: 0.0810 - precision: 0.7415 - recall: 0.3427 - val_accuracy: 0.9681 - val_loss: 0.1018 - val_precision: 0.7791 - val_recall: 0.3009 - learning_rate: 0.0010
# Epoch 17/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9748 - loss: 0.0806 - precision: 0.7570 - recall: 0.3489 - val_accuracy: 0.9682 - val_loss: 0.1015 - val_precision: 0.7668 - val_recall: 0.3134 - learning_rate: 0.0010
# Epoch 18/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9747 - loss: 0.0803 - precision: 0.7492 - recall: 0.3489 - val_accuracy: 0.9682 - val_loss: 0.1031 - val_precision: 0.7655 - val_recall: 0.3136 - learning_rate: 0.0010
# Epoch 19/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9748 - loss: 0.0801 - precision: 0.7523 - recall: 0.3536 - val_accuracy: 0.9678 - val_loss: 0.1026 - val_precision: 0.7751 - val_recall: 0.2923 - learning_rate: 0.0010
# Epoch 20/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9746 - loss: 0.0797 - precision: 0.7438 - recall: 0.3517 - val_accuracy: 0.9680 - val_loss: 0.1028 - val_precision: 0.7667 - val_recall: 0.3058 - learning_rate: 0.0010
# Epoch 21/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9748 - loss: 0.0796 - precision: 0.7511 - recall: 0.3554 - val_accuracy: 0.9679 - val_loss: 0.1025 - val_precision: 0.7705 - val_recall: 0.2983 - learning_rate: 0.0010
# Epoch 22/100
# 3672/3674 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9749 - loss: 0.0792 - precision: 0.7535 - recall: 0.3575
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9749 - loss: 0.0792 - precision: 0.7535 - recall: 0.3575 - val_accuracy: 0.9680 - val_loss: 0.1019 - val_precision: 0.7813 - val_recall: 0.2941 - learning_rate: 0.0010
# Epoch 23/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9750 - loss: 0.0780 - precision: 0.7585 - recall: 0.3578 - val_accuracy: 0.9679 - val_loss: 0.1020 - val_precision: 0.7436 - val_recall: 0.3216 - learning_rate: 5.0000e-04
# Epoch 24/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9750 - loss: 0.0773 - precision: 0.7477 - recall: 0.3666 - val_accuracy: 0.9679 - val_loss: 0.1018 - val_precision: 0.7560 - val_recall: 0.3119 - learning_rate: 5.0000e-04
# Epoch 25/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9752 - loss: 0.0773 - precision: 0.7601 - recall: 0.3640 - val_accuracy: 0.9680 - val_loss: 0.1019 - val_precision: 0.7540 - val_recall: 0.3174 - learning_rate: 5.0000e-04
# Epoch 26/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9755 - loss: 0.0771 - precision: 0.7621 - recall: 0.3744 - val_accuracy: 0.9678 - val_loss: 0.1017 - val_precision: 0.7432 - val_recall: 0.3162 - learning_rate: 5.0000e-04
# Epoch 27/100
# 3672/3674 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9756 - loss: 0.0767 - precision: 0.7645 - recall: 0.3754
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9756 - loss: 0.0767 - precision: 0.7646 - recall: 0.3754 - val_accuracy: 0.9677 - val_loss: 0.1026 - val_precision: 0.7507 - val_recall: 0.3067 - learning_rate: 5.0000e-04

# %% [markdown]
# ### 3.3 Avaliação do Modelo

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

y_pred_probs = lstm_model.predict(X_test_norm).flatten()
y_pred_labels = (y_pred_probs >= 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test_seq, y_pred_labels))

cm = confusion_matrix(y_test_seq, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Sem casos', 'Com casos'])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM Classificação")
plt.grid(False)
plt.show()
# Out:
# 2852/2852 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     82271
#            1       0.76      0.36      0.49      8990
#
#     accuracy                           0.93     91261
#    macro avg       0.85      0.67      0.72     91261
# weighted avg       0.92      0.93      0.91     91261

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    roc_curve,
    precision_recall_curve,
    balanced_accuracy_score,
    f1_score
)

# %%
# AUC-ROC
roc_auc = roc_auc_score(y_test_seq, y_pred_probs)

# AUC-PR
pr_auc = average_precision_score(y_test_seq, y_pred_probs)

# Balanced Accuracy
bal_acc = balanced_accuracy_score(y_test_seq, y_pred_labels)

# F1 Score
f1 = f1_score(y_test_seq, y_pred_labels)

print(f"\nMétricas adicionais:")
print(f"AUC-ROC: {roc_auc:.4f}")
print(f"AUC-PR : {pr_auc:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Balanced Accuracy: {bal_acc:.4f}")
# Out:
# Métricas adicionais:
# AUC-ROC: 0.9020
# AUC-PR : 0.6133
# F1 Score: 0.4890
# Balanced Accuracy: 0.6738

# %%
# ROC Curve
fpr, tpr, _ = roc_curve(y_test_seq, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], 'k--', label="Random")
plt.xlabel("FPR (1 - Especificidade)")
plt.ylabel("TPR (Sensibilidade)")
plt.title("Curva ROC")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test_seq, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(recall, precision, label=f"AP = {pr_auc:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Curva Precision-Recall")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Resumo Crítico
#
# - O modelo é conservador: prefere errar por omissão (não prever dengue quando tem) do que por alarme falso.
#
# - Ele é muito bom em evitar falsos positivos, mas perde muitos casos reais, o que pode ser crítico em contexto de saúde pública.
#
# - O AUC-ROC alto indica que o modelo poderia ser calibrado para melhorar o recall, ajustando o threshold de decisão (por padrão é 0.5).

# %% [markdown]
# ## 4 - Regressão

# %% [markdown]
# ### 4.1 Pré-processamento

# %%
# PRE PROCESSAMENTO

# Função para criar janelas temporais
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(window_size, len(X)):
        X_seq.append(X[i-window_size:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

# Definindo janela
window_size = 7

# Criando janelas
X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
X_val_seq, y_val_seq = create_sequences(X_val, y_val, window_size)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

# Normalização
X_scaler = MinMaxScaler()
X_train_flat = X_train_seq.reshape(-1, X_train_seq.shape[2])
X_val_flat = X_val_seq.reshape(-1, X_val_seq.shape[2])
X_test_flat = X_test_seq.reshape(-1, X_test_seq.shape[2])

X_scaler.fit(X_train_flat)
X_train_norm = X_scaler.transform(X_train_flat).reshape(X_train_seq.shape)
X_val_norm = X_scaler.transform(X_val_flat).reshape(X_val_seq.shape)
X_test_norm = X_scaler.transform(X_test_flat).reshape(X_test_seq.shape)

# Filtrar apenas alvos com casos > 0
y_train_real = y_train[window_size:]
y_val_real = y_val[window_size:]
y_test_real = y_test[window_size:]

mask_train = y_train_real > 0
mask_val = y_val_real > 0
mask_test = y_test_real > 0

X_train_reg = X_train_norm[mask_train]
y_train_reg = y_train_real[mask_train]
X_val_reg = X_val_norm[mask_val]
y_val_reg = y_val_real[mask_val]
X_test_reg = X_test_norm[mask_test]
y_test_reg = y_test_real[mask_test]

# %% [markdown]
# ### 4.2 LSTM

# %% [markdown]
# #### Funções auxiliares

# %%
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error

def reset_seeds(seed):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()

def build_improved_lstm(input_shape):
    """Construção do modelo com melhores práticas"""
    model = Sequential([
        Input(shape=input_shape),
        LSTM(64, return_sequences=False, kernel_initializer='glorot_uniform'),
        Dropout(0.3),
        Dense(32, activation='relu', kernel_initializer='he_normal'),
        Dropout(0.2),
        Dense(1, activation='linear')
    ])
    
    optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
    model.compile(optimizer=optimizer, loss='huber', metrics=['mae'])
    return model

def robust_evaluation(model, X_test, y_test):
    """Avaliação robusta com métricas adicionais"""
    y_pred = model.predict(X_test).flatten()
    
    metrics = {
        'MAE': mean_absolute_error(y_test, y_pred),
        'RMSE': root_mean_squared_error(y_test, y_pred),
        'R2': r2_score(y_test, y_pred),
        'MaxError': np.max(np.abs(y_test - y_pred)),
        'MedianAE': np.median(np.abs(y_test - y_pred))
    }
    
    return metrics

# %% [markdown]
# #### Rodadas com diferentes Seeds

# %%
def run_multiple_seeds(n_runs=5, seed_start=42):
    """Execução com múltiplas seeds e análise estatística"""
    all_metrics = []
    input_shape = (X_train_reg.shape[1], X_train_reg.shape[2])
    
    for i in range(n_runs):
        current_seed = seed_start + i
        print(f"\n--- Execução {i+1}/{n_runs} (Seed: {current_seed}) ---")
        reset_seeds(current_seed)
        
        model = build_improved_lstm(input_shape)
        
        callbacks = [
            EarlyStopping(patience=10, restore_best_weights=True, 
                         monitor='val_loss', mode='min'),
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                            patience=5, verbose=1),
            ModelCheckpoint(f'best_model_seed_{current_seed}.keras',
                          save_best_only=True, monitor='val_loss')
        ]
        
        history = model.fit(
            X_train_reg, y_train_reg,
            validation_data=(X_val_reg, y_val_reg),
            epochs=100,
            batch_size=64,
            callbacks=callbacks,
            verbose=1  # Mantemos visibilidade do treinamento
        )
        
        metrics = robust_evaluation(model, X_test_reg, y_test_reg)
        all_metrics.append(metrics)
        
        print(f"MAE: {metrics['MAE']:.2f} | RMSE: {metrics['RMSE']:.2f} | R²: {metrics['R2']:.4f}")
    
    # Análise estatística
    print("\n=== Resultados Consolidados ===")
    for metric in ['MAE', 'RMSE', 'R2', 'MaxError', 'MedianAE']:
        values = [m[metric] for m in all_metrics]
        print(f"{metric}:")
        print(f"  Média = {np.mean(values):.4f}")
        print(f"  Desvio Padrão = {np.std(values):.4f}")
        print(f"  Min = {np.min(values):.4f}")
        print(f"  Max = {np.max(values):.4f}")
        print(f"  Intervalo = [{np.min(values):.4f}, {np.max(values):.4f}]\n")
    
    return all_metrics

# Execução principal
final_metrics = run_multiple_seeds(n_runs=5)
# Out:
# --- Execução 1/5 (Seed: 42) ---
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 5.1176 - mae: 5.5393 - val_loss: 2.0487 - val_mae: 2.4331 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5904 - mae: 4.9871 - val_loss: 1.9095 - val_mae: 2.3140 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.0738 - mae: 4.4624 - val_loss: 1.7821 - val_mae: 2.1601 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.7005 - mae: 4.0841 - val_loss: 1.7354 - val_mae: 2.1059 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.4121 - mae: 3.7935 - val_loss: 1.7342 - val_mae: 2.0767 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2312 - mae: 3.6131 - val_loss: 1.7633 - val_mae: 2.0660 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0855 - mae: 3.4623 - val_loss: 1.7437 - val_mae: 2.0543 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0324 - mae: 3.4073 - val_loss: 1.7820 - val_mae: 2.0926 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9983 - mae: 3.3758 - val_loss: 1.7042 - val_mae: 2.0287 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9471 - mae: 3.3199 - val_loss: 1.7314 - val_mae: 2.0318 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0120 - mae: 3.3902 - val_loss: 1.6522 - val_mae: 2.0236 - learning_rate: 0.0010
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.9065 - mae: 3.2857 - val_loss: 1.6432 - val_mae: 1.9959 - learning_rate: 0.0010
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9146 - mae: 3.2885 - val_loss: 1.6332 - val_mae: 2.0092 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8819 - mae: 3.2604 - val_loss: 1.6368 - val_mae: 2.0109 - learning_rate: 0.0010
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8959 - mae: 3.2719 - val_loss: 1.6288 - val_mae: 2.0245 - learning_rate: 0.0010
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8744 - mae: 3.2541 - val_loss: 1.6331 - val_mae: 1.9922 - learning_rate: 0.0010
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.9152 - mae: 3.2933 - val_loss: 1.6214 - val_mae: 1.9884 - learning_rate: 0.0010
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7917 - mae: 3.1685 - val_loss: 1.6451 - val_mae: 1.9884 - learning_rate: 0.0010
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8715 - mae: 3.2450 - val_loss: 1.6288 - val_mae: 2.0161 - learning_rate: 0.0010
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.8476 - mae: 3.2280 - val_loss: 1.6422 - val_mae: 1.9844 - learning_rate: 0.0010
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.8968 - mae: 3.2749 - val_loss: 1.6131 - val_mae: 2.0076 - learning_rate: 0.0010
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8049 - mae: 3.1862 - val_loss: 1.6376 - val_mae: 2.0162 - learning_rate: 0.0010
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8704 - mae: 3.2540 - val_loss: 1.5963 - val_mae: 1.9932 - learning_rate: 0.0010
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7916 - mae: 3.1702 - val_loss: 1.5962 - val_mae: 1.9933 - learning_rate: 0.0010
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.7834 - mae: 3.1583 - val_loss: 1.5868 - val_mae: 1.9829 - learning_rate: 0.0010
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7368 - mae: 3.1155 - val_loss: 1.6099 - val_mae: 2.0043 - learning_rate: 0.0010
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7422 - mae: 3.1245 - val_loss: 1.5974 - val_mae: 1.9728 - learning_rate: 0.0010
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6822 - mae: 3.0645 - val_loss: 1.6160 - val_mae: 2.0060 - learning_rate: 0.0010
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7608 - mae: 3.1450 - val_loss: 1.6006 - val_mae: 1.9861 - learning_rate: 0.0010
# Epoch 30/100
# 106/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7358 - mae: 3.1198
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7138 - mae: 3.0968 - val_loss: 1.6002 - val_mae: 1.9807 - learning_rate: 0.0010
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7095 - mae: 3.1003 - val_loss: 1.5797 - val_mae: 1.9724 - learning_rate: 5.0000e-04
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7135 - mae: 3.0967 - val_loss: 1.5912 - val_mae: 1.9823 - learning_rate: 5.0000e-04
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7103 - mae: 3.0960 - val_loss: 1.5823 - val_mae: 1.9786 - learning_rate: 5.0000e-04
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7174 - mae: 3.1034 - val_loss: 1.5836 - val_mae: 1.9769 - learning_rate: 5.0000e-04
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6285 - mae: 3.0137 - val_loss: 1.5903 - val_mae: 1.9834 - learning_rate: 5.0000e-04
# Epoch 36/100
# 118/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6911 - mae: 3.0761
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6856 - mae: 3.0704 - val_loss: 1.5879 - val_mae: 1.9719 - learning_rate: 5.0000e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6311 - mae: 3.0173 - val_loss: 1.5913 - val_mae: 1.9691 - learning_rate: 2.5000e-04
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6457 - mae: 3.0299 - val_loss: 1.5956 - val_mae: 1.9705 - learning_rate: 2.5000e-04
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5948 - mae: 2.9787 - val_loss: 1.5814 - val_mae: 1.9620 - learning_rate: 2.5000e-04
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7492 - mae: 3.1294 - val_loss: 1.5808 - val_mae: 1.9679 - learning_rate: 2.5000e-04
# Epoch 41/100
# 111/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5781 - mae: 2.9656
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5634 - mae: 2.9500 - val_loss: 1.5822 - val_mae: 1.9713 - learning_rate: 2.5000e-04
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.80 | RMSE: 4.43 | R²: 0.5599
#
# --- Execução 2/5 (Seed: 43) ---
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.7898 - mae: 5.1991 - val_loss: 2.0358 - val_mae: 2.4325 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.3732 - mae: 4.7678 - val_loss: 1.8799 - val_mae: 2.2460 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9241 - mae: 4.3092 - val_loss: 1.9925 - val_mae: 2.2900 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5712 - mae: 3.9477 - val_loss: 1.8820 - val_mae: 2.1744 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.3994 - mae: 3.7748 - val_loss: 1.7910 - val_mae: 2.1025 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2139 - mae: 3.5871 - val_loss: 1.7407 - val_mae: 2.1196 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1586 - mae: 3.5357 - val_loss: 1.7750 - val_mae: 2.1092 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.1056 - mae: 3.4805 - val_loss: 1.6898 - val_mae: 2.0731 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0618 - mae: 3.4368 - val_loss: 1.7137 - val_mae: 2.0381 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0133 - mae: 3.3868 - val_loss: 1.7046 - val_mae: 2.0689 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9575 - mae: 3.3327 - val_loss: 1.6854 - val_mae: 2.0362 - learning_rate: 0.0010
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0328 - mae: 3.4081 - val_loss: 1.6686 - val_mae: 2.0551 - learning_rate: 0.0010
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9024 - mae: 3.2820 - val_loss: 1.6719 - val_mae: 2.0370 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9444 - mae: 3.3191 - val_loss: 1.6736 - val_mae: 2.0381 - learning_rate: 0.0010
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8842 - mae: 3.2573 - val_loss: 1.6959 - val_mae: 2.0318 - learning_rate: 0.0010
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8573 - mae: 3.2294 - val_loss: 1.6712 - val_mae: 2.0173 - learning_rate: 0.0010
# Epoch 17/100
# 114/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9162 - mae: 3.2879
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9063 - mae: 3.2784 - val_loss: 1.6843 - val_mae: 2.0303 - learning_rate: 0.0010
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7128 - mae: 3.0838 - val_loss: 1.6301 - val_mae: 1.9997 - learning_rate: 5.0000e-04
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6981 - mae: 3.0763 - val_loss: 1.6273 - val_mae: 1.9920 - learning_rate: 5.0000e-04
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7294 - mae: 3.1061 - val_loss: 1.6284 - val_mae: 1.9977 - learning_rate: 5.0000e-04
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6964 - mae: 3.0740 - val_loss: 1.6499 - val_mae: 1.9845 - learning_rate: 5.0000e-04
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7015 - mae: 3.0731 - val_loss: 1.6408 - val_mae: 1.9815 - learning_rate: 5.0000e-04
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7594 - mae: 3.1320 - val_loss: 1.6433 - val_mae: 1.9837 - learning_rate: 5.0000e-04
# Epoch 24/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7084 - mae: 3.0793
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7063 - mae: 3.0772 - val_loss: 1.6423 - val_mae: 1.9701 - learning_rate: 5.0000e-04
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6874 - mae: 3.0529 - val_loss: 1.6024 - val_mae: 1.9863 - learning_rate: 2.5000e-04
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6852 - mae: 3.0597 - val_loss: 1.6027 - val_mae: 1.9765 - learning_rate: 2.5000e-04
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6765 - mae: 3.0520 - val_loss: 1.6085 - val_mae: 1.9746 - learning_rate: 2.5000e-04
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6470 - mae: 3.0200 - val_loss: 1.5983 - val_mae: 1.9793 - learning_rate: 2.5000e-04
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7404 - mae: 3.1150 - val_loss: 1.6020 - val_mae: 1.9677 - learning_rate: 2.5000e-04
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7080 - mae: 3.0791 - val_loss: 1.6158 - val_mae: 1.9682 - learning_rate: 2.5000e-04
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6977 - mae: 3.0654 - val_loss: 1.6023 - val_mae: 1.9801 - learning_rate: 2.5000e-04
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6522 - mae: 3.0268 - val_loss: 1.6096 - val_mae: 1.9733 - learning_rate: 2.5000e-04
# Epoch 33/100
# 110/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6224 - mae: 2.9923
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6180 - mae: 2.9884 - val_loss: 1.6055 - val_mae: 1.9645 - learning_rate: 2.5000e-04
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6632 - mae: 3.0330 - val_loss: 1.5956 - val_mae: 1.9802 - learning_rate: 1.2500e-04
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6059 - mae: 2.9826 - val_loss: 1.5969 - val_mae: 1.9724 - learning_rate: 1.2500e-04
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6164 - mae: 2.9915 - val_loss: 1.5955 - val_mae: 1.9747 - learning_rate: 1.2500e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6661 - mae: 3.0424 - val_loss: 1.5898 - val_mae: 1.9689 - learning_rate: 1.2500e-04
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6211 - mae: 2.9975 - val_loss: 1.5998 - val_mae: 1.9796 - learning_rate: 1.2500e-04
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6455 - mae: 3.0197 - val_loss: 1.5939 - val_mae: 1.9718 - learning_rate: 1.2500e-04
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6310 - mae: 3.0087 - val_loss: 1.5851 - val_mae: 1.9670 - learning_rate: 1.2500e-04
# Epoch 41/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6221 - mae: 2.9974 - val_loss: 1.5983 - val_mae: 1.9763 - learning_rate: 1.2500e-04
# Epoch 42/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6133 - mae: 2.9904 - val_loss: 1.5892 - val_mae: 1.9630 - learning_rate: 1.2500e-04
# Epoch 43/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6523 - mae: 3.0236 - val_loss: 1.5897 - val_mae: 1.9706 - learning_rate: 1.2500e-04
# Epoch 44/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6207 - mae: 2.9955 - val_loss: 1.5846 - val_mae: 1.9665 - learning_rate: 1.2500e-04
# Epoch 45/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6105 - mae: 2.9880 - val_loss: 1.5879 - val_mae: 1.9653 - learning_rate: 1.2500e-04
# Epoch 46/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6218 - mae: 2.9949 - val_loss: 1.5954 - val_mae: 1.9704 - learning_rate: 1.2500e-04
# Epoch 47/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5389 - mae: 2.9116 - val_loss: 1.5842 - val_mae: 1.9648 - learning_rate: 1.2500e-04
# Epoch 48/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5697 - mae: 2.9431 - val_loss: 1.5971 - val_mae: 1.9688 - learning_rate: 1.2500e-04
# Epoch 49/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5615 - mae: 2.9337 - val_loss: 1.5926 - val_mae: 1.9656 - learning_rate: 1.2500e-04
# Epoch 50/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6039 - mae: 2.9770 - val_loss: 1.5847 - val_mae: 1.9611 - learning_rate: 1.2500e-04
# Epoch 51/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5850 - mae: 2.9595 - val_loss: 1.5833 - val_mae: 1.9671 - learning_rate: 1.2500e-04
# Epoch 52/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5946 - mae: 2.9734 - val_loss: 1.5843 - val_mae: 1.9591 - learning_rate: 1.2500e-04
# Epoch 53/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6151 - mae: 2.9868 - val_loss: 1.5898 - val_mae: 1.9631 - learning_rate: 1.2500e-04
# Epoch 54/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6139 - mae: 2.9871 - val_loss: 1.5822 - val_mae: 1.9576 - learning_rate: 1.2500e-04
# Epoch 55/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6005 - mae: 2.9727 - val_loss: 1.5869 - val_mae: 1.9627 - learning_rate: 1.2500e-04
# Epoch 56/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5803 - mae: 2.9514 - val_loss: 1.5823 - val_mae: 1.9580 - learning_rate: 1.2500e-04
# Epoch 57/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5546 - mae: 2.9302 - val_loss: 1.5848 - val_mae: 1.9558 - learning_rate: 1.2500e-04
# Epoch 58/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5597 - mae: 2.9316 - val_loss: 1.5844 - val_mae: 1.9606 - learning_rate: 1.2500e-04
# Epoch 59/100
# 104/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6532 - mae: 3.0285
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6350 - mae: 3.0103 - val_loss: 1.5886 - val_mae: 1.9595 - learning_rate: 1.2500e-04
# Epoch 60/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5470 - mae: 2.9188 - val_loss: 1.5887 - val_mae: 1.9608 - learning_rate: 6.2500e-05
# Epoch 61/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5732 - mae: 2.9447 - val_loss: 1.5817 - val_mae: 1.9622 - learning_rate: 6.2500e-05
# Epoch 62/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5424 - mae: 2.9177 - val_loss: 1.5887 - val_mae: 1.9648 - learning_rate: 6.2500e-05
# Epoch 63/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6388 - mae: 3.0139 - val_loss: 1.5863 - val_mae: 1.9645 - learning_rate: 6.2500e-05
# Epoch 64/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5480 - mae: 2.9214 - val_loss: 1.5884 - val_mae: 1.9589 - learning_rate: 6.2500e-05
# Epoch 65/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5915 - mae: 2.9615 - val_loss: 1.5800 - val_mae: 1.9559 - learning_rate: 6.2500e-05
# Epoch 66/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6464 - mae: 3.0221 - val_loss: 1.5838 - val_mae: 1.9576 - learning_rate: 6.2500e-05
# Epoch 67/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5694 - mae: 2.9400 - val_loss: 1.5807 - val_mae: 1.9565 - learning_rate: 6.2500e-05
# Epoch 68/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5688 - mae: 2.9435 - val_loss: 1.5835 - val_mae: 1.9553 - learning_rate: 6.2500e-05
# Epoch 69/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6040 - mae: 2.9787 - val_loss: 1.5914 - val_mae: 1.9685 - learning_rate: 6.2500e-05
# Epoch 70/100
# 106/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5824 - mae: 2.9561
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5762 - mae: 2.9499 - val_loss: 1.5863 - val_mae: 1.9612 - learning_rate: 6.2500e-05
# Epoch 71/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6155 - mae: 2.9915 - val_loss: 1.5851 - val_mae: 1.9635 - learning_rate: 3.1250e-05
# Epoch 72/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5320 - mae: 2.9082 - val_loss: 1.5853 - val_mae: 1.9605 - learning_rate: 3.1250e-05
# Epoch 73/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6119 - mae: 2.9870 - val_loss: 1.5823 - val_mae: 1.9596 - learning_rate: 3.1250e-05
# Epoch 74/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5206 - mae: 2.8953 - val_loss: 1.5859 - val_mae: 1.9589 - learning_rate: 3.1250e-05
# Epoch 75/100
# 100/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5807 - mae: 2.9530
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5713 - mae: 2.9436 - val_loss: 1.5824 - val_mae: 1.9590 - learning_rate: 3.1250e-05
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.76 | RMSE: 4.33 | R²: 0.5795
#
# --- Execução 3/5 (Seed: 44) ---
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.6896 - mae: 5.1039 - val_loss: 2.0502 - val_mae: 2.4557 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.2866 - mae: 4.6786 - val_loss: 1.9214 - val_mae: 2.2606 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8900 - mae: 4.2775 - val_loss: 1.9683 - val_mae: 2.2754 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5987 - mae: 3.9826 - val_loss: 1.7805 - val_mae: 2.1157 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3523 - mae: 3.7360 - val_loss: 1.8208 - val_mae: 2.1252 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2099 - mae: 3.5882 - val_loss: 1.7565 - val_mae: 2.0731 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1551 - mae: 3.5327 - val_loss: 1.7384 - val_mae: 2.0439 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0488 - mae: 3.4219 - val_loss: 1.7258 - val_mae: 2.0436 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.9648 - mae: 3.3374 - val_loss: 1.7171 - val_mae: 2.0259 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9869 - mae: 3.3586 - val_loss: 1.7261 - val_mae: 2.0321 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9272 - mae: 3.2993 - val_loss: 1.6975 - val_mae: 2.0121 - learning_rate: 0.0010
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8687 - mae: 3.2407 - val_loss: 1.6979 - val_mae: 2.0178 - learning_rate: 0.0010
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8609 - mae: 3.2361 - val_loss: 1.7244 - val_mae: 2.0346 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7949 - mae: 3.1680 - val_loss: 1.7727 - val_mae: 2.0658 - learning_rate: 0.0010
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8319 - mae: 3.2020 - val_loss: 1.7319 - val_mae: 2.0328 - learning_rate: 0.0010
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8014 - mae: 3.1724 - val_loss: 1.6827 - val_mae: 2.0092 - learning_rate: 0.0010
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7916 - mae: 3.1647 - val_loss: 1.7013 - val_mae: 2.0173 - learning_rate: 0.0010
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8267 - mae: 3.2014 - val_loss: 1.7200 - val_mae: 2.0259 - learning_rate: 0.0010
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7508 - mae: 3.1201 - val_loss: 1.7113 - val_mae: 2.0214 - learning_rate: 0.0010
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6723 - mae: 3.0444 - val_loss: 1.6620 - val_mae: 1.9894 - learning_rate: 0.0010
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6979 - mae: 3.0673 - val_loss: 1.6944 - val_mae: 2.0319 - learning_rate: 0.0010
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7390 - mae: 3.1101 - val_loss: 1.6920 - val_mae: 2.0457 - learning_rate: 0.0010
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6279 - mae: 3.0059 - val_loss: 1.7185 - val_mae: 2.0277 - learning_rate: 0.0010
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6891 - mae: 3.0630 - val_loss: 1.6609 - val_mae: 2.0021 - learning_rate: 0.0010
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6828 - mae: 3.0580 - val_loss: 1.6491 - val_mae: 2.0142 - learning_rate: 0.0010
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6558 - mae: 3.0363 - val_loss: 1.6615 - val_mae: 2.0134 - learning_rate: 0.0010
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6316 - mae: 3.0062 - val_loss: 1.6541 - val_mae: 2.0054 - learning_rate: 0.0010
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6490 - mae: 3.0276 - val_loss: 1.7160 - val_mae: 2.0468 - learning_rate: 0.0010
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6414 - mae: 3.0191 - val_loss: 1.6579 - val_mae: 2.0231 - learning_rate: 0.0010
# Epoch 30/100
# 112/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6189 - mae: 3.0035
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6178 - mae: 3.0023 - val_loss: 1.6555 - val_mae: 2.0078 - learning_rate: 0.0010
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6006 - mae: 2.9782 - val_loss: 1.6192 - val_mae: 1.9882 - learning_rate: 5.0000e-04
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5909 - mae: 2.9659 - val_loss: 1.6242 - val_mae: 1.9872 - learning_rate: 5.0000e-04
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5647 - mae: 2.9413 - val_loss: 1.6152 - val_mae: 1.9937 - learning_rate: 5.0000e-04
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5592 - mae: 2.9373 - val_loss: 1.6346 - val_mae: 1.9996 - learning_rate: 5.0000e-04
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5737 - mae: 2.9511 - val_loss: 1.6160 - val_mae: 1.9941 - learning_rate: 5.0000e-04
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5846 - mae: 2.9664 - val_loss: 1.6079 - val_mae: 1.9766 - learning_rate: 5.0000e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5579 - mae: 2.9323 - val_loss: 1.5827 - val_mae: 1.9635 - learning_rate: 5.0000e-04
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5726 - mae: 2.9493 - val_loss: 1.5839 - val_mae: 1.9840 - learning_rate: 5.0000e-04
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6204 - mae: 3.0011 - val_loss: 1.6058 - val_mae: 1.9767 - learning_rate: 5.0000e-04
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5274 - mae: 2.9038 - val_loss: 1.5992 - val_mae: 1.9764 - learning_rate: 5.0000e-04
# Epoch 41/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5758 - mae: 2.9523 - val_loss: 1.5905 - val_mae: 1.9708 - learning_rate: 5.0000e-04
# Epoch 42/100
#  99/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5300 - mae: 2.9096
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5376 - mae: 2.9169 - val_loss: 1.5952 - val_mae: 1.9736 - learning_rate: 5.0000e-04
# Epoch 43/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5093 - mae: 2.8872 - val_loss: 1.5746 - val_mae: 1.9601 - learning_rate: 2.5000e-04
# Epoch 44/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4384 - mae: 2.8168 - val_loss: 1.5793 - val_mae: 1.9692 - learning_rate: 2.5000e-04
# Epoch 45/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4696 - mae: 2.8518 - val_loss: 1.5777 - val_mae: 1.9666 - learning_rate: 2.5000e-04
# Epoch 46/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5312 - mae: 2.9110 - val_loss: 1.5784 - val_mae: 1.9694 - learning_rate: 2.5000e-04
# Epoch 47/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5172 - mae: 2.8968 - val_loss: 1.5959 - val_mae: 1.9835 - learning_rate: 2.5000e-04
# Epoch 48/100
# 114/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4765 - mae: 2.8552
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4739 - mae: 2.8524 - val_loss: 1.5872 - val_mae: 1.9791 - learning_rate: 2.5000e-04
# Epoch 49/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4293 - mae: 2.8161 - val_loss: 1.5910 - val_mae: 1.9681 - learning_rate: 1.2500e-04
# Epoch 50/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4078 - mae: 2.7883 - val_loss: 1.5955 - val_mae: 1.9637 - learning_rate: 1.2500e-04
# Epoch 51/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4364 - mae: 2.8145 - val_loss: 1.5889 - val_mae: 1.9655 - learning_rate: 1.2500e-04
# Epoch 52/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5134 - mae: 2.8941 - val_loss: 1.5847 - val_mae: 1.9603 - learning_rate: 1.2500e-04
# Epoch 53/100
# 108/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4147 - mae: 2.7918
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4177 - mae: 2.7949 - val_loss: 1.5851 - val_mae: 1.9564 - learning_rate: 1.2500e-04
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.78 | RMSE: 4.41 | R²: 0.5649
#
# --- Execução 4/5 (Seed: 45) ---
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.6856 - mae: 5.1014 - val_loss: 2.0543 - val_mae: 2.4406 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.2843 - mae: 4.6741 - val_loss: 1.8644 - val_mae: 2.2656 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8876 - mae: 4.2725 - val_loss: 1.8123 - val_mae: 2.2298 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5383 - mae: 3.9209 - val_loss: 1.7430 - val_mae: 2.1150 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.2812 - mae: 3.6571 - val_loss: 1.7353 - val_mae: 2.0891 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.1483 - mae: 3.5242 - val_loss: 1.7039 - val_mae: 2.0942 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0580 - mae: 3.4358 - val_loss: 1.6803 - val_mae: 2.0626 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9264 - mae: 3.3027 - val_loss: 1.6589 - val_mae: 2.0238 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8881 - mae: 3.2636 - val_loss: 1.6688 - val_mae: 2.0154 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8453 - mae: 3.2167 - val_loss: 1.6329 - val_mae: 1.9882 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8192 - mae: 3.1914 - val_loss: 1.6940 - val_mae: 2.0027 - learning_rate: 0.0010
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7574 - mae: 3.1281 - val_loss: 1.6179 - val_mae: 1.9759 - learning_rate: 0.0010
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7909 - mae: 3.1624 - val_loss: 1.6634 - val_mae: 1.9752 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7470 - mae: 3.1201 - val_loss: 1.6107 - val_mae: 1.9681 - learning_rate: 0.0010
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7336 - mae: 3.1074 - val_loss: 1.6322 - val_mae: 1.9822 - learning_rate: 0.0010
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7123 - mae: 3.0847 - val_loss: 1.6262 - val_mae: 1.9594 - learning_rate: 0.0010
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6128 - mae: 2.9792 - val_loss: 1.5970 - val_mae: 1.9814 - learning_rate: 0.0010
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6924 - mae: 3.0667 - val_loss: 1.6208 - val_mae: 1.9768 - learning_rate: 0.0010
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7448 - mae: 3.1163 - val_loss: 1.6028 - val_mae: 1.9615 - learning_rate: 0.0010
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6994 - mae: 3.0714 - val_loss: 1.5980 - val_mae: 1.9616 - learning_rate: 0.0010
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6397 - mae: 3.0083 - val_loss: 1.5925 - val_mae: 1.9716 - learning_rate: 0.0010
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6374 - mae: 3.0059 - val_loss: 1.6253 - val_mae: 1.9888 - learning_rate: 0.0010
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5962 - mae: 2.9677 - val_loss: 1.6061 - val_mae: 1.9631 - learning_rate: 0.0010
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6163 - mae: 2.9859 - val_loss: 1.5934 - val_mae: 1.9720 - learning_rate: 0.0010
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6121 - mae: 2.9825 - val_loss: 1.6075 - val_mae: 1.9671 - learning_rate: 0.0010
# Epoch 26/100
# 103/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5854 - mae: 2.9595
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5982 - mae: 2.9724 - val_loss: 1.6018 - val_mae: 1.9540 - learning_rate: 0.0010
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6282 - mae: 2.9981 - val_loss: 1.5886 - val_mae: 1.9557 - learning_rate: 5.0000e-04
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.5485 - mae: 2.9202 - val_loss: 1.5806 - val_mae: 1.9677 - learning_rate: 5.0000e-04
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5627 - mae: 2.9385 - val_loss: 1.6062 - val_mae: 1.9858 - learning_rate: 5.0000e-04
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5500 - mae: 2.9243 - val_loss: 1.6020 - val_mae: 1.9892 - learning_rate: 5.0000e-04
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5657 - mae: 2.9363 - val_loss: 1.5992 - val_mae: 1.9756 - learning_rate: 5.0000e-04
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5532 - mae: 2.9297 - val_loss: 1.6001 - val_mae: 1.9930 - learning_rate: 5.0000e-04
# Epoch 33/100
# 114/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5338 - mae: 2.9069
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5385 - mae: 2.9116 - val_loss: 1.5941 - val_mae: 1.9756 - learning_rate: 5.0000e-04
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4680 - mae: 2.8435 - val_loss: 1.5902 - val_mae: 1.9705 - learning_rate: 2.5000e-04
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4709 - mae: 2.8487 - val_loss: 1.5853 - val_mae: 1.9572 - learning_rate: 2.5000e-04
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5349 - mae: 2.9067 - val_loss: 1.5939 - val_mae: 1.9698 - learning_rate: 2.5000e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5212 - mae: 2.8936 - val_loss: 1.6067 - val_mae: 1.9723 - learning_rate: 2.5000e-04
# Epoch 38/100
# 104/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4518 - mae: 2.8252
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4640 - mae: 2.8378 - val_loss: 1.6015 - val_mae: 1.9758 - learning_rate: 2.5000e-04
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.77 | RMSE: 4.37 | R²: 0.5715
#
# --- Execução 5/5 (Seed: 46) ---
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.7185 - mae: 5.1294 - val_loss: 2.1103 - val_mae: 2.4329 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.2837 - mae: 4.6718 - val_loss: 2.0633 - val_mae: 2.3857 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.8676 - mae: 4.2459 - val_loss: 1.9700 - val_mae: 2.2809 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6012 - mae: 3.9766 - val_loss: 1.8475 - val_mae: 2.1633 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3909 - mae: 3.7634 - val_loss: 1.7992 - val_mae: 2.1162 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2445 - mae: 3.6149 - val_loss: 1.7607 - val_mae: 2.1514 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1039 - mae: 3.4822 - val_loss: 1.7300 - val_mae: 2.1162 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0229 - mae: 3.3949 - val_loss: 1.6947 - val_mae: 2.0674 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0534 - mae: 3.4292 - val_loss: 1.7018 - val_mae: 2.0500 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9918 - mae: 3.3628 - val_loss: 1.6690 - val_mae: 2.0816 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9892 - mae: 3.3671 - val_loss: 1.6629 - val_mae: 2.0438 - learning_rate: 0.0010
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8570 - mae: 3.2315 - val_loss: 1.6585 - val_mae: 2.0508 - learning_rate: 0.0010
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8895 - mae: 3.2615 - val_loss: 1.6696 - val_mae: 2.0622 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8425 - mae: 3.2213 - val_loss: 1.6581 - val_mae: 2.0391 - learning_rate: 0.0010
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7968 - mae: 3.1757 - val_loss: 1.6689 - val_mae: 2.0398 - learning_rate: 0.0010
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8533 - mae: 3.2312 - val_loss: 1.6411 - val_mae: 2.0535 - learning_rate: 0.0010
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8022 - mae: 3.1834 - val_loss: 1.6416 - val_mae: 2.0188 - learning_rate: 0.0010
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8029 - mae: 3.1763 - val_loss: 1.6598 - val_mae: 2.0156 - learning_rate: 0.0010
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7375 - mae: 3.1106 - val_loss: 1.6227 - val_mae: 2.0148 - learning_rate: 0.0010
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7561 - mae: 3.1322 - val_loss: 1.6405 - val_mae: 1.9940 - learning_rate: 0.0010
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7309 - mae: 3.1005 - val_loss: 1.6284 - val_mae: 2.0172 - learning_rate: 0.0010
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8397 - mae: 3.2157 - val_loss: 1.6648 - val_mae: 2.0090 - learning_rate: 0.0010
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7192 - mae: 3.0889 - val_loss: 1.6256 - val_mae: 2.0040 - learning_rate: 0.0010
# Epoch 24/100
# 110/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7808 - mae: 3.1605
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7710 - mae: 3.1503 - val_loss: 1.6388 - val_mae: 2.0465 - learning_rate: 0.0010
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6835 - mae: 3.0639 - val_loss: 1.6172 - val_mae: 2.0205 - learning_rate: 5.0000e-04
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6563 - mae: 3.0284 - val_loss: 1.6121 - val_mae: 2.0145 - learning_rate: 5.0000e-04
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.5537 - mae: 2.9339 - val_loss: 1.6026 - val_mae: 1.9893 - learning_rate: 5.0000e-04
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6039 - mae: 2.9759 - val_loss: 1.6079 - val_mae: 1.9864 - learning_rate: 5.0000e-04
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5825 - mae: 2.9514 - val_loss: 1.6268 - val_mae: 2.0280 - learning_rate: 5.0000e-04
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5881 - mae: 2.9630 - val_loss: 1.5990 - val_mae: 1.9912 - learning_rate: 5.0000e-04
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6280 - mae: 3.0041 - val_loss: 1.5944 - val_mae: 1.9924 - learning_rate: 5.0000e-04
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6043 - mae: 2.9782 - val_loss: 1.6011 - val_mae: 1.9915 - learning_rate: 5.0000e-04
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5199 - mae: 2.8918 - val_loss: 1.5978 - val_mae: 1.9861 - learning_rate: 5.0000e-04
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5833 - mae: 2.9582 - val_loss: 1.6222 - val_mae: 2.0264 - learning_rate: 5.0000e-04
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5630 - mae: 2.9378 - val_loss: 1.6064 - val_mae: 2.0045 - learning_rate: 5.0000e-04
# Epoch 36/100
# 119/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6206 - mae: 2.9915
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6194 - mae: 2.9904 - val_loss: 1.6099 - val_mae: 2.0015 - learning_rate: 5.0000e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5444 - mae: 2.9209 - val_loss: 1.6043 - val_mae: 1.9860 - learning_rate: 2.5000e-04
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5808 - mae: 2.9532 - val_loss: 1.5958 - val_mae: 1.9943 - learning_rate: 2.5000e-04
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5367 - mae: 2.9130 - val_loss: 1.5986 - val_mae: 1.9896 - learning_rate: 2.5000e-04
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5559 - mae: 2.9355 - val_loss: 1.6129 - val_mae: 1.9916 - learning_rate: 2.5000e-04
# Epoch 41/100
# 119/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5562 - mae: 2.9298
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5543 - mae: 2.9278 - val_loss: 1.6095 - val_mae: 1.9918 - learning_rate: 2.5000e-04
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.77 | RMSE: 4.33 | R²: 0.5804
#
# === Resultados Consolidados ===
# MAE:
#   Média = 1.7765
#   Desvio Padrão = 0.0130
#   Min = 1.7629
#   Max = 1.8010
#   Intervalo = [1.7629, 1.8010]
#
# RMSE:
#   Média = 4.3759
#   Desvio Padrão = 0.0409
#   Min = 4.3289
#   Max = 4.4336
#   Intervalo = [4.3289, 4.4336]
#
# R2:
#   Média = 0.5712
#   Desvio Padrão = 0.0080
#   Min = 0.5599
#   Max = 0.5804
#   Intervalo = [0.5599, 0.5804]
#
# MaxError:
#   Média = 99.5132
#   Desvio Padrão = 1.2727
#   Min = 97.8166
#   Max = 101.4795
#   Intervalo = [97.8166, 101.4795]
#
# MedianAE:
#   Média = 0.5900
#   Desvio Padrão = 0.0149
#   Min = 0.5768
#   Max = 0.6185
#   Intervalo = [0.5768, 0.6185]

# %% [markdown]
# #### Avaliando as estatísticas:

# %% [markdown]
# Execução 1/5 (Seed: 42) ---
# MAE: 1.96 | RMSE: 4.67 | R²: 0.5114
#
# Execução 2/5 (Seed: 43) ---
# MAE: 2.13 | RMSE: 4.56 | R²: 0.5343
#
#
# Execução 3/5 (Seed: 44) ---
# MAE: 1.93 | RMSE: 4.65 | R²: 0.5159
#
# Execução 4/5 (Seed: 45) ---
# MAE: 2.03 | RMSE: 4.76 | R²: 0.4925
#
# Execução 5/5 (Seed: 46) ---
# MAE: 1.99 | RMSE: 4.31 | R²: 0.5841
#
# === Resultados Consolidados ===
#
# MAE:<br>
#   Média = 2.0071 <br>
#   Desvio Padrão = 0.0689<br>
#   Min = 1.9251<br>
#   Max = 2.1270<br>
#   Intervalo = [1.9251, 2.1270]<br>
# <br>
# RMSE:<br>
#   Média = 4.5906<br>
#   Desvio Padrão = 0.1541<br>
#   Min = 4.3099<br>
#   Max = 4.7609<br>
#   Intervalo = [4.3099, 4.7609]<br>
# <br>
# R2:<br>
#   Média = 0.5276<br>
#   Desvio Padrão = 0.0312<br>
#   Min = 0.4925<br>
#   Max = 0.5841<br>
#   Intervalo = [0.4925, 0.5841]<br>
# <br>
# MaxError:<br>
#   Média = 107.4861<br>
#   Desvio Padrão = 4.4748<br>
#   Min = 101.4885<br>
#   Max = 115.1247<br>
#   Intervalo = [101.4885, 115.1247]<br>
# <br>
# MedianAE:<br>
#   Média = 1.0648<br>
#   Desvio Padrão = 0.1815<br>
#   Min = 0.7532<br>
#   Max = 1.2921<br>
#   Intervalo = [0.7532, 1.2921]

# %% [markdown]
# ### 4.3 Conv1D

# %% [markdown]
# #### Definindo seed

# %%
def reset_seeds(seed):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()

# %% [markdown]
# #### Arquitetura do modelo

# %%
def build_conv1d_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        Conv1D(64, kernel_size=3, activation='relu', padding='same',
               kernel_initializer='he_normal'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),
        Conv1D(32, kernel_size=3, activation='relu', padding='same',
               kernel_initializer='he_normal'),
        MaxPooling1D(pool_size=1),
        Dropout(0.3),
        Flatten(),
        Dense(32, activation='relu', kernel_initializer='he_normal'),
        Dropout(0.2),
        Dense(1, activation='linear')
    ])

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='huber',
                  metrics=['mae'])
    return model

# %% [markdown]
# #### Funções de avaliação do modelo

# %%
def evaluate_model_metrics(model, X_test, y_test):
    y_pred = model.predict(X_test).flatten()

    return {
        'MAE': mean_absolute_error(y_test, y_pred),
        'RMSE': root_mean_squared_error(y_test, y_pred),
        'R2': r2_score(y_test, y_pred),
        'MaxError': np.max(np.abs(y_test - y_pred)),
        'MedianAE': np.median(np.abs(y_test - y_pred)),
        'y_true': y_test,
        'y_pred': y_pred
    }

# %%
def plot_predictions(y_true, y_pred, title="Dispersão - Valores Reais vs Previstos"):
    plt.figure(figsize=(6, 6))
    plt.scatter(y_true, y_pred, alpha=0.4, color='royalblue', s=10)
    plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()],
             'r--', lw=2, label="Ideal")
    plt.xlabel("Casos Reais")
    plt.ylabel("Casos Previstos")
    plt.title(title)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Rodadas com diferentes seeds

# %%
def run_conv1d_experiments(n_runs=5, seed_start=42):
    all_metrics = []
    input_shape = (X_train_reg.shape[1], X_train_reg.shape[2])

    for i in range(n_runs):
        current_seed = seed_start + i
        print(f"\n--- Execução {i+1}/{n_runs} (Seed: {current_seed}) ---")
        reset_seeds(current_seed)

        model = build_conv1d_model(input_shape)

        callbacks = [
            EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=0),
            ModelCheckpoint(f'modelos/best_conv1d_seed_{current_seed}.keras',
                            save_best_only=True, monitor='val_loss', verbose=0)
        ]

        model.fit(
            X_train_reg, y_train_reg,
            validation_data=(X_val_reg, y_val_reg),
            epochs=100,
            batch_size=64,
            callbacks=callbacks,
            verbose=0  # reduz saída
        )

        result = evaluate_model_metrics(model, X_test_reg, y_test_reg)
        all_metrics.append(result)

        print(f"MAE: {result['MAE']:.2f} | RMSE: {result['RMSE']:.2f} | R²: {result['R2']:.4f}")

    return all_metrics

# %% [markdown]
# #### Função de análise

# %%
def analyze_results(all_metrics):
    print("\n=== Resultados Consolidados (Conv1D) ===")
    for metric in ['MAE', 'RMSE', 'R2', 'MaxError', 'MedianAE']:
        values = [m[metric] for m in all_metrics]
        print(f"\n{metric}:")
        print(f"  Média = {np.mean(values):.4f}")
        print(f"  Desvio Padrão = {np.std(values):.4f}")
        print(f"  Min = {np.min(values):.4f}")
        print(f"  Max = {np.max(values):.4f}")
        print(f"  Intervalo = [{np.min(values):.4f}, {np.max(values):.4f}]")

    # Gráfico de dispersão da última execução
    plt.figure(figsize=(6, 6))
    plt.scatter(all_metrics[-1]['y_true'], all_metrics[-1]['y_pred'], alpha=0.5, color='royalblue', s=10)
    plt.plot([all_metrics[-1]['y_true'].min(), all_metrics[-1]['y_true'].max()],
            [all_metrics[-1]['y_true'].min(), all_metrics[-1]['y_true'].max()],
            'r--', lw=2, label="Ideal")

    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel("Casos Reais (log)")
    plt.ylabel("Casos Previstos (log)")
    plt.title("Dispersão da Última Execução - Conv1D (Escala Log)")
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Evolução das execuções
    plt.figure(figsize=(10, 4))
    plt.plot([m['MAE'] for m in all_metrics], 'o-', label='MAE')
    plt.plot([m['R2'] for m in all_metrics], 'o-', label='R²')
    plt.title('Variação das Métricas por Execução')
    plt.xlabel('Execução')
    plt.ylabel('Valor')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
conv1d_metrics = run_conv1d_experiments(n_runs=5)
# Out:
# --- Execução 1/5 (Seed: 42) ---
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.90 | RMSE: 4.73 | R²: 0.4993
#
# --- Execução 2/5 (Seed: 43) ---
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 2.02 | RMSE: 5.16 | R²: 0.4043
#
# --- Execução 3/5 (Seed: 44) ---
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.97 | RMSE: 4.90 | R²: 0.4621
#
# --- Execução 4/5 (Seed: 45) ---
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.99 | RMSE: 4.96 | R²: 0.4500
#
# --- Execução 5/5 (Seed: 46) ---
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MAE: 1.98 | RMSE: 4.88 | R²: 0.4658

# %%
analyze_results(conv1d_metrics)
# Out:
# === Resultados Consolidados (Conv1D) ===
#
# MAE:
#   Média = 1.9704
#   Desvio Padrão = 0.0394
#   Min = 1.8989
#   Max = 2.0171
#   Intervalo = [1.8989, 2.0171]
#
# RMSE:
#   Média = 4.9259
#   Desvio Padrão = 0.1385
#   Min = 4.7290
#   Max = 5.1581
#   Intervalo = [4.7290, 5.1581]
#
# R2:
#   Média = 0.4563
#   Desvio Padrão = 0.0307
#   Min = 0.4043
#   Max = 0.4993
#   Intervalo = [0.4043, 0.4993]
#
# MaxError:
#   Média = 119.8136
#   Desvio Padrão = 3.3156
#   Min = 115.3796
#   Max = 124.0516
#   Intervalo = [115.3796, 124.0516]
#
# MedianAE:
#   Média = 0.6179
#   Desvio Padrão = 0.0212
#   Min = 0.5905
#   Max = 0.6560
#   Intervalo = [0.5905, 0.6560]

# %% [markdown]
# ### 4.4 Avaliação dos Modelos

# %% [markdown]
# ## 5 - Investigação da sensibilidade dos modelos
