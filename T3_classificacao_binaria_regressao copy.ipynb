# %% [markdown]
# <a id="top"></a>
# <div class="list-group" id="list-tab" role="tablist">
# <h1 class="list-group-item list-group-item-action active" data-toggle="list" style='background:#005097; border:0' role="tab" aria-controls="home"><center>APRENDIZADO DE MÁQUINA (GCC1932) - Trabalho 3</center></h1>
#
# - Nome completo: Bianca Gallicchio Tavares
# - [Link para vídeo](https://youtu.be/pR8AvE2IriM)

# %% [markdown]
# ## 0 - Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import tensorflow as tf
from tensorflow.keras import backend as K
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Conv1D, Dense, Dropout, Flatten, MaxPooling1D, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Configurações
plt.style.use('ggplot')
sns.set_palette("husl")
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 1 - Carregando o dataset

# %%
def load_and_analyze(data_path, feature_dict_path):
    """Carrega dados e realiza análise exploratória"""
    # Carregamento
    with open(data_path, 'rb') as f:
        X_train, y_train, X_val, y_val, X_test, y_test = pickle.load(f)
    
    feature_dict = pd.read_csv(feature_dict_path)
    
    # Análise de distribuição
    print("\nDistribuição dos Casos:")
    print(f"Total de casos (treino): {y_train.sum()}")
    print(f"Média semanal (treino): {y_train.mean():.2f}")
    print(f"Máximo em uma semana: {y_train.max()}")
    
    plt.figure(figsize=(10, 5))
    plt.hist(y_train, bins=50, alpha=0.7, label='Treino')
    plt.hist(y_val, bins=50, alpha=0.7, label='Validação')
    plt.hist(y_test, bins=50, alpha=0.7, label='Teste')
    plt.title('Distribuição dos Casos de Dengue')
    plt.legend()
    plt.show()
    
    return X_train, y_train, X_val, y_val, X_test, y_test, feature_dict

# %%
data_path = 'DATASETS/RJ_WEEKLY/dataset.pickle'
feature_dict_path = 'DATASETS/RJ_WEEKLY/feature_dictionary.csv'
X_train, y_train, X_val, y_val, X_test, y_test, feature_dict = load_and_analyze(data_path, feature_dict_path)
# Out:
# Distribuição dos Casos:
# Total de casos (treino): 47117
# Média semanal (treino): 0.20
# Máximo em uma semana: 337

# %% [markdown]
# ### Dicionário de Features

# %% [markdown]
# Este dicionário é gerado automaticamente durante a criação do dataset, baseado nas colunas do DataFrame final antes da conversão para NumPy.
#
# 1. **TEM_AVG**: Temperatura média diária (°C)
# 2. **TEM_MIN**: Temperatura mínima diária (°C)
# 3. **TEM_MAX**: Temperatura máxima diária (°C)
# 4. **RAIN**: Precipitação total diária (mm)
# 5. **RH_AVG**: Umidade relativa média do dia (%)
# 6. **RH_MIN**: Umidade relativa mínima do dia (%)
# 7. **RH_MAX**: Umidade relativa máxima do dia (%)
# 8. **IDEAL_TEMP**: Temperatura ideal para eclosão de ovos e amadurecimento do mosquito (°C)
# 9. **EXTREME_TEMP**: Temperatura nociva para o mosquito (°C)
# 10. **SIGNIFICANT_RAIN**: Chuva significativa capaz de criar novos criadouros (mm)
# 11. **EXTREME_RAIN**: Chuva extrema que remove ovos do ambiente (mm)
# 12. **TEMP_RANGE**: Amplitude térmica do dia (°C)
# 13. **WEEK_OF_YEAR**: Semana epidemiológica (1 a 52)
# 14. **TEM_AVG_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 15. **CASES_MM_7**: Número de casos reportados
# 16. **CASES_ACC_7**: Número de casos reportados
# 17. **RAIN_ACC_7**: Valor acumulado (soma ao longo do tempo)
# 18. **RAIN_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 19. **RH_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 20. **TEMP_RANGE_MM_7**: Amplitude térmica do dia (°C)
# 21. **TEM_AVG_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 22. **CASES_MM_14**: Número de casos reportados
# 23. **CASES_ACC_14**: Número de casos reportados
# 24. **RAIN_ACC_14**: Valor acumulado (soma ao longo do tempo)
# 25. **RAIN_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 26. **RH_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 27. **TEMP_RANGE_MM_14**: Amplitude térmica do dia (°C)
# 28. **TEM_AVG_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 29. **CASES_MM_21**: Número de casos reportados
# 30. **CASES_ACC_21**: Número de casos reportados
# 31. **RAIN_ACC_21**: Valor acumulado (soma ao longo do tempo)
# 32. **RAIN_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 33. **RH_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 34. **TEMP_RANGE_MM_21**: Amplitude térmica do dia (°C)
# 35. **TEM_AVG_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 36. **CASES_MM_28**: Número de casos reportados
# 37. **CASES_ACC_28**: Número de casos reportados
# 38. **RAIN_ACC_28**: Valor acumulado (soma ao longo do tempo)
# 39. **RAIN_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 40. **RH_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 41. **TEMP_RANGE_MM_28**: Amplitude térmica do dia (°C)
# 42. **CASES_LAG_1**: Número de casos reportados
# 43. **CASES_LAG_2**: Número de casos reportados
# 44. **CASES_LAG_3**: Número de casos reportados
# 45. **CASES_LAG_4**: Número de casos reportados
# 46. **CASES_LAG_5**: Número de casos reportados
# 47. **CASES_LAG_6**: Número de casos reportados

# %% [markdown]
# ## 2 - Análise Exploratória

# %%
# Carregando o dicionário de features para entender as variáveis
feature_dict = pd.read_csv('DATASETS/RJ_WEEKLY/feature_dictionary.csv')
print("\nDicionário de Variáveis:")
print(feature_dict)
# Out:
# Dicionário de Variáveis:
#     Index           Feature
# 0       0           TEM_AVG
# 1       1           TEM_MIN
# 2       2           TEM_MAX
# 3       3              RAIN
# 4       4            RH_AVG
# 5       5            RH_MIN
# 6       6            RH_MAX
# 7       7        CASES_MM_7
# 8       8       CASES_MM_14
# 9       9       CASES_MM_21
# 10     10       CASES_MM_28
# 11     11       CASES_ACC_7
# 12     12      CASES_ACC_14
# 13     13      CASES_ACC_21
# 14     14      CASES_ACC_28
# 15     15       CASES_LAG_1
# 16     16       CASES_LAG_2
# 17     17       CASES_LAG_3
# 18     18       CASES_LAG_4
# 19     19       CASES_LAG_5
# 20     20       CASES_LAG_6
# 21     21        IDEAL_TEMP
# 22     22      EXTREME_TEMP
# 23     23  SIGNIFICANT_RAIN
# 24     24      EXTREME_RAIN
# 25     25        TEMP_RANGE
# 26     26      WEEK_OF_YEAR
# 27     27      TEM_AVG_MM_7
# 28     28        RAIN_ACC_7
# 29     29         RAIN_MM_7
# 30     30           RH_MM_7
# 31     31   TEMP_RANGE_MM_7
# 32     32     TEM_AVG_MM_14
# 33     33       RAIN_ACC_14
# 34     34        RAIN_MM_14
# 35     35          RH_MM_14
# 36     36  TEMP_RANGE_MM_14
# 37     37     TEM_AVG_MM_21
# 38     38       RAIN_ACC_21
# 39     39        RAIN_MM_21
# 40     40          RH_MM_21
# 41     41  TEMP_RANGE_MM_21
# 42     42     TEM_AVG_MM_28
# 43     43       RAIN_ACC_28
# 44     44        RAIN_MM_28
# 45     45          RH_MM_28
# 46     46  TEMP_RANGE_MM_28

# %%
# Verificando a dimensionalidade dos dados
print("\nDimensionalidade dos dados:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Dimensionalidade dos dados:
# X_train shape: (235118, 47)
# y_train shape: (235118,)

# %% [markdown]
# O dataset é **altamente desbalanceado**, com a maioria das observações registrando **zero casos** de dengue.
# Essa característica é comum em contextos epidemiológicos onde a maioria dos dias/unidades não apresentam surtos.

# %%
# Estatísticas de distribuição de classes
n_total = len(y_train)
n_positive = np.sum(y_train > 0)
n_zero = n_total - n_positive
pct_positive = (n_positive / n_total) * 100

print(f"Total de amostras: {n_total}")
print(f"Com casos (>0): {n_positive} ({pct_positive:.2f}%)")
print(f"Sem casos (=0): {n_zero} ({100 - pct_positive:.2f}%)")
# Out:
# Total de amostras: 235118
# Com casos (>0): 7805 (3.32%)
# Sem casos (=0): 227313 (96.68%)

# %%
# Correlações com variáveis climáticas
cases_related_vars = [
    'CASES_MM_7', 'CASES_ACC_7', 'CASES_MM_14', 'CASES_ACC_14',
    'CASES_MM_21', 'CASES_ACC_21', 'CASES_MM_28', 'CASES_ACC_28',
    'CASES_LAG_1', 'CASES_LAG_2', 'CASES_LAG_3', 'CASES_LAG_4',
    'CASES_LAG_5', 'CASES_LAG_6'
]
climate_vars = [f for f in feature_dict['Feature'] if f not in cases_related_vars]

df_train_climate = pd.DataFrame(X_train, columns=feature_dict['Feature'])
df_train_climate = df_train_climate[climate_vars]
df_train_climate['Casos'] = y_train

corr_matrix_climate = df_train_climate.corr()

plt.figure(figsize=(12, 6))
corr_matrix_climate['Casos'].sort_values(ascending=False)[:-1].plot(kind='bar')
plt.title('Correlação entre Variáveis Climáticas e Casos de Dengue')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Mostrando as 10 variáveis climáticas mais correlacionadas
print("\nTop 10 variáveis CLIMÁTICAS mais correlacionadas com Casos de Dengue:")
print(corr_matrix_climate['Casos'].sort_values(ascending=False).head(11)[1:])  # Pula a correlação consigo mesmo

print("\nTop 10 variáveis CLIMÁTICAS mais negativamente correlacionadas com Casos de Dengue:")
print(corr_matrix_climate['Casos'].sort_values().head(10))
# Out:
# Top 10 variáveis CLIMÁTICAS mais correlacionadas com Casos de Dengue:
# Feature
# RAIN_ACC_21     0.032468
# RAIN_MM_21      0.032468
# RAIN_ACC_28     0.031881
# RAIN_MM_28      0.031881
# RAIN_MM_14      0.027074
# RAIN_ACC_14     0.027074
# RH_MM_7         0.018568
# RH_MM_14        0.016504
# RH_AVG          0.015392
# EXTREME_TEMP    0.014736
# Name: Casos, dtype: float64
#
# Top 10 variáveis CLIMÁTICAS mais negativamente correlacionadas com Casos de Dengue:
# Feature
# WEEK_OF_YEAR       -0.031065
# TEMP_RANGE_MM_7    -0.025737
# TEMP_RANGE_MM_14   -0.023960
# TEMP_RANGE         -0.017104
# TEM_MAX            -0.015629
# TEMP_RANGE_MM_21   -0.014926
# TEM_AVG            -0.003996
# TEMP_RANGE_MM_28   -0.003591
# SIGNIFICANT_RAIN   -0.002144
# TEM_MIN            -0.001036
# Name: Casos, dtype: float64

# %% [markdown]
# ## 3 - Classificação Binária

# %% [markdown]
# ### 3.1 Pré-processamento

# %%
# Transformando y em binário (1 = caso, 0 = sem caso)
y_train_bin = (y_train > 0).astype(int)
y_val_bin = (y_val > 0).astype(int)
y_test_bin = (y_test > 0).astype(int)

# %% [markdown]
# #### Criando janelas temporais

# %%
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(window_size, len(X)):
        X_seq.append(X[i-window_size:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

window_size = 14

X_train_seq, y_train_seq = create_sequences(X_train, y_train_bin, window_size)
X_val_seq, y_val_seq = create_sequences(X_val, y_val_bin, window_size)
X_test_seq, y_test_seq = create_sequences(X_test, y_test_bin, window_size)

# %% [markdown]
# #### Normalização

# %%
X_scaler = MinMaxScaler()

X_train_flat = X_train_seq.reshape(-1, X_train_seq.shape[2])
X_val_flat = X_val_seq.reshape(-1, X_val_seq.shape[2])
X_test_flat = X_test_seq.reshape(-1, X_test_seq.shape[2])

X_scaler.fit(X_train_flat)

X_train_norm = X_scaler.transform(X_train_flat).reshape(X_train_seq.shape)
X_val_norm = X_scaler.transform(X_val_flat).reshape(X_val_seq.shape)
X_test_norm = X_scaler.transform(X_test_flat).reshape(X_test_seq.shape)

# %% [markdown]
# ### 3.2 Modelo LSTM

# %%
lstm_model = Sequential([
    Input(shape=(window_size, X_train_norm.shape[2])),
    LSTM(64, return_sequences=False),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # Saída binária
])

lstm_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, verbose=1),
    ModelCheckpoint('melhor_lstm_classificacao.keras', save_best_only=True, monitor='val_loss')
]

# %%
history_lstm = lstm_model.fit(
    X_train_norm, y_train_seq,
    validation_data=(X_val_norm, y_val_seq),
    epochs=100,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - accuracy: 0.9679 - loss: 0.1384 - precision: 0.5625 - recall: 0.0689 - val_accuracy: 0.9657 - val_loss: 0.1181 - val_precision: 0.6908 - val_recall: 0.2813 - learning_rate: 0.0010
# Epoch 2/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9724 - loss: 0.0983 - precision: 0.6992 - recall: 0.2879 - val_accuracy: 0.9673 - val_loss: 0.1104 - val_precision: 0.7148 - val_recall: 0.3234 - learning_rate: 0.0010
# Epoch 3/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9734 - loss: 0.0915 - precision: 0.7112 - recall: 0.3251 - val_accuracy: 0.9679 - val_loss: 0.1059 - val_precision: 0.7586 - val_recall: 0.3085 - learning_rate: 0.0010
# Epoch 4/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9734 - loss: 0.0888 - precision: 0.7102 - recall: 0.3247 - val_accuracy: 0.9680 - val_loss: 0.1074 - val_precision: 0.7549 - val_recall: 0.3132 - learning_rate: 0.0010
# Epoch 5/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9740 - loss: 0.0870 - precision: 0.7314 - recall: 0.3359 - val_accuracy: 0.9682 - val_loss: 0.1067 - val_precision: 0.7436 - val_recall: 0.3306 - learning_rate: 0.0010
# Epoch 6/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9737 - loss: 0.0859 - precision: 0.7209 - recall: 0.3294 - val_accuracy: 0.9681 - val_loss: 0.1054 - val_precision: 0.7706 - val_recall: 0.3065 - learning_rate: 0.0010
# Epoch 7/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9741 - loss: 0.0849 - precision: 0.7301 - recall: 0.3432 - val_accuracy: 0.9684 - val_loss: 0.1051 - val_precision: 0.7580 - val_recall: 0.3255 - learning_rate: 0.0010
# Epoch 8/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9740 - loss: 0.0843 - precision: 0.7350 - recall: 0.3334 - val_accuracy: 0.9681 - val_loss: 0.1050 - val_precision: 0.7770 - val_recall: 0.3001 - learning_rate: 0.0010
# Epoch 9/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9741 - loss: 0.0835 - precision: 0.7359 - recall: 0.3346 - val_accuracy: 0.9679 - val_loss: 0.1026 - val_precision: 0.7756 - val_recall: 0.2963 - learning_rate: 0.0010
# Epoch 10/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9743 - loss: 0.0833 - precision: 0.7458 - recall: 0.3335 - val_accuracy: 0.9683 - val_loss: 0.1032 - val_precision: 0.7600 - val_recall: 0.3220 - learning_rate: 0.0010
# Epoch 11/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9745 - loss: 0.0827 - precision: 0.7496 - recall: 0.3413 - val_accuracy: 0.9680 - val_loss: 0.1016 - val_precision: 0.7773 - val_recall: 0.2974 - learning_rate: 0.0010
# Epoch 12/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9744 - loss: 0.0827 - precision: 0.7463 - recall: 0.3414 - val_accuracy: 0.9681 - val_loss: 0.1005 - val_precision: 0.7702 - val_recall: 0.3080 - learning_rate: 0.0010
# Epoch 13/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9745 - loss: 0.0820 - precision: 0.7514 - recall: 0.3406 - val_accuracy: 0.9683 - val_loss: 0.0993 - val_precision: 0.7696 - val_recall: 0.3153 - learning_rate: 0.0010
# Epoch 14/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9745 - loss: 0.0817 - precision: 0.7483 - recall: 0.3410 - val_accuracy: 0.9682 - val_loss: 0.0996 - val_precision: 0.7699 - val_recall: 0.3118 - learning_rate: 0.0010
# Epoch 15/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.9746 - loss: 0.0813 - precision: 0.7522 - recall: 0.3448 - val_accuracy: 0.9683 - val_loss: 0.1008 - val_precision: 0.7729 - val_recall: 0.3101 - learning_rate: 0.0010
# Epoch 16/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9746 - loss: 0.0808 - precision: 0.7459 - recall: 0.3505 - val_accuracy: 0.9686 - val_loss: 0.1002 - val_precision: 0.7592 - val_recall: 0.3330 - learning_rate: 0.0010
# Epoch 17/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9746 - loss: 0.0807 - precision: 0.7496 - recall: 0.3453 - val_accuracy: 0.9683 - val_loss: 0.1004 - val_precision: 0.7631 - val_recall: 0.3183 - learning_rate: 0.0010
# Epoch 18/100
# 3663/3674 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0804 - precision: 0.7499 - recall: 0.3560
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9748 - loss: 0.0804 - precision: 0.7499 - recall: 0.3560 - val_accuracy: 0.9684 - val_loss: 0.1016 - val_precision: 0.7628 - val_recall: 0.3224 - learning_rate: 0.0010
# Epoch 19/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9748 - loss: 0.0790 - precision: 0.7463 - recall: 0.3566 - val_accuracy: 0.9684 - val_loss: 0.1003 - val_precision: 0.7590 - val_recall: 0.3257 - learning_rate: 5.0000e-04
# Epoch 20/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9750 - loss: 0.0786 - precision: 0.7566 - recall: 0.3586 - val_accuracy: 0.9684 - val_loss: 0.1000 - val_precision: 0.7658 - val_recall: 0.3205 - learning_rate: 5.0000e-04
# Epoch 21/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9750 - loss: 0.0782 - precision: 0.7590 - recall: 0.3556 - val_accuracy: 0.9683 - val_loss: 0.1010 - val_precision: 0.7608 - val_recall: 0.3219 - learning_rate: 5.0000e-04
# Epoch 22/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9752 - loss: 0.0778 - precision: 0.7597 - recall: 0.3625 - val_accuracy: 0.9683 - val_loss: 0.1004 - val_precision: 0.7687 - val_recall: 0.3158 - learning_rate: 5.0000e-04
# Epoch 23/100
# 3673/3674 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9750 - loss: 0.0780 - precision: 0.7542 - recall: 0.3603
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9750 - loss: 0.0780 - precision: 0.7542 - recall: 0.3603 - val_accuracy: 0.9686 - val_loss: 0.1005 - val_precision: 0.7638 - val_recall: 0.3285 - learning_rate: 5.0000e-04

# %% [markdown]
# ### 3.3 Avaliação do Modelo

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

y_pred_probs = lstm_model.predict(X_test_norm).flatten()
y_pred_labels = (y_pred_probs >= 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test_seq, y_pred_labels))

cm = confusion_matrix(y_test_seq, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Sem casos', 'Com casos'])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM Classificação")
plt.grid(False)
plt.show()
# Out:
# 2852/2852 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     82271
#            1       0.75      0.35      0.48      8990
#
#     accuracy                           0.92     91261
#    macro avg       0.84      0.67      0.72     91261
# weighted avg       0.92      0.92      0.91     91261

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    roc_curve,
    precision_recall_curve,
    balanced_accuracy_score,
    f1_score
)

# %%
# AUC-ROC
roc_auc = roc_auc_score(y_test_seq, y_pred_probs)

# AUC-PR
pr_auc = average_precision_score(y_test_seq, y_pred_probs)

# Balanced Accuracy
bal_acc = balanced_accuracy_score(y_test_seq, y_pred_labels)

# F1 Score
f1 = f1_score(y_test_seq, y_pred_labels)

print(f"\nMétricas adicionais:")
print(f"AUC-ROC: {roc_auc:.4f}")
print(f"AUC-PR : {pr_auc:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Balanced Accuracy: {bal_acc:.4f}")
# Out:
# Métricas adicionais:
# AUC-ROC: 0.9063
# AUC-PR : 0.6071
# F1 Score: 0.4753
# Balanced Accuracy: 0.6673

# %%
# ROC Curve
fpr, tpr, _ = roc_curve(y_test_seq, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], 'k--', label="Random")
plt.xlabel("FPR (1 - Especificidade)")
plt.ylabel("TPR (Sensibilidade)")
plt.title("Curva ROC")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test_seq, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(recall, precision, label=f"AP = {pr_auc:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Curva Precision-Recall")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Resumo Crítico
#
# - O modelo é conservador: prefere errar por omissão (não prever dengue quando tem) do que por alarme falso.
#
# - Ele é muito bom em evitar falsos positivos, mas perde muitos casos reais, o que pode ser crítico em contexto de saúde pública.
#
# - O AUC-ROC alto indica que o modelo poderia ser calibrado para melhorar o recall, ajustando o threshold de decisão (por padrão é 0.5).

# %% [markdown]
# ## 4 - Regressão

# %% [markdown]
# ### 4.1 Pré-processamento

# %%
from sklearn.preprocessing import MinMaxScaler

# Função para criar janelas temporais
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(window_size, len(X)):
        X_seq.append(X[i-window_size:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

# Definindo janela
window_size = 7

# Criando janelas
X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
X_val_seq, y_val_seq = create_sequences(X_val, y_val, window_size)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

# Normalização
X_scaler = MinMaxScaler()
X_train_flat = X_train_seq.reshape(-1, X_train_seq.shape[2])
X_val_flat = X_val_seq.reshape(-1, X_val_seq.shape[2])
X_test_flat = X_test_seq.reshape(-1, X_test_seq.shape[2])

X_scaler.fit(X_train_flat)
X_train_norm = X_scaler.transform(X_train_flat).reshape(X_train_seq.shape)
X_val_norm = X_scaler.transform(X_val_flat).reshape(X_val_seq.shape)
X_test_norm = X_scaler.transform(X_test_flat).reshape(X_test_seq.shape)

# Filtrar apenas alvos com casos > 0
y_train_real = y_train[window_size:]
y_val_real = y_val[window_size:]
y_test_real = y_test[window_size:]

mask_train = y_train_real > 0
mask_val = y_val_real > 0
mask_test = y_test_real > 0

X_train_reg = X_train_norm[mask_train]
y_train_reg = y_train_real[mask_train]
X_val_reg = X_val_norm[mask_val]
y_val_reg = y_val_real[mask_val]
X_test_reg = X_test_norm[mask_test]
y_test_reg = y_test_real[mask_test]

# %% [markdown]
# ### 4.2 LSTM

# %%
# Construção
lstm_model = Sequential([
    Input(shape=(window_size, X_train_reg.shape[2])),
    LSTM(64, return_sequences=False),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='linear')
])

lstm_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Callbacks
lstm_callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1),
    ModelCheckpoint('lstm_regressao.keras', save_best_only=True)
]

# Treinamento
history_lstm = lstm_model.fit(
    X_train_reg, y_train_reg,
    validation_data=(X_val_reg, y_val_reg),
    epochs=100,
    batch_size=64,
    callbacks=lstm_callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 427.0155 - mae: 6.4989 - val_loss: 43.2677 - val_mae: 2.9235 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 327.2129 - mae: 5.5638 - val_loss: 50.7319 - val_mae: 3.9076 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 241.2311 - mae: 5.0253 - val_loss: 39.5533 - val_mae: 2.6519 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 200.6152 - mae: 4.5159 - val_loss: 43.0517 - val_mae: 2.8407 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 181.8652 - mae: 4.4844 - val_loss: 37.0056 - val_mae: 2.5468 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 155.7623 - mae: 4.1685 - val_loss: 41.0157 - val_mae: 2.7203 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 139.8865 - mae: 4.0340 - val_loss: 37.5253 - val_mae: 2.4246 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 140.0322 - mae: 3.9602 - val_loss: 34.8388 - val_mae: 2.4706 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 126.5281 - mae: 3.8962 - val_loss: 37.7539 - val_mae: 2.5730 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 123.3721 - mae: 3.8240 - val_loss: 36.5365 - val_mae: 2.5021 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 112.3773 - mae: 3.7803 - val_loss: 34.2939 - val_mae: 2.5797 - learning_rate: 0.0010
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 113.1204 - mae: 3.7942 - val_loss: 34.8725 - val_mae: 2.6365 - learning_rate: 0.0010
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.5713 - mae: 3.8955 - val_loss: 33.1299 - val_mae: 2.6590 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 116.3218 - mae: 3.8330 - val_loss: 30.4220 - val_mae: 2.4508 - learning_rate: 0.0010
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 113.9900 - mae: 3.7741 - val_loss: 30.1831 - val_mae: 2.5132 - learning_rate: 0.0010
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 121.0683 - mae: 3.9014 - val_loss: 31.8338 - val_mae: 2.4933 - learning_rate: 0.0010
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 112.0072 - mae: 3.8032 - val_loss: 31.4456 - val_mae: 2.3876 - learning_rate: 0.0010
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 122.5614 - mae: 3.7915 - val_loss: 30.9253 - val_mae: 2.3973 - learning_rate: 0.0010
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 108.0873 - mae: 3.8089 - val_loss: 29.0916 - val_mae: 2.3387 - learning_rate: 0.0010
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 106.4319 - mae: 3.6561 - val_loss: 29.5147 - val_mae: 2.3482 - learning_rate: 0.0010
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 116.2623 - mae: 3.6669 - val_loss: 28.1792 - val_mae: 2.4530 - learning_rate: 0.0010
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 118.9246 - mae: 3.8244 - val_loss: 29.0229 - val_mae: 2.4581 - learning_rate: 0.0010
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 103.6639 - mae: 3.6598 - val_loss: 29.4324 - val_mae: 2.4308 - learning_rate: 0.0010
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 102.1484 - mae: 3.6797 - val_loss: 27.5428 - val_mae: 2.4110 - learning_rate: 0.0010
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 104.2922 - mae: 3.6999 - val_loss: 28.5304 - val_mae: 2.3391 - learning_rate: 0.0010
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 109.4418 - mae: 3.6906 - val_loss: 28.3085 - val_mae: 2.3952 - learning_rate: 0.0010
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 92.3941 - mae: 3.6099 - val_loss: 28.4934 - val_mae: 2.5248 - learning_rate: 0.0010
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 113.5113 - mae: 3.7447 - val_loss: 29.5465 - val_mae: 2.2827 - learning_rate: 0.0010
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 95.7385 - mae: 3.4903
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 95.6898 - mae: 3.4895 - val_loss: 28.6421 - val_mae: 2.4598 - learning_rate: 0.0010
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 90.0273 - mae: 3.5295 - val_loss: 26.4131 - val_mae: 2.3070 - learning_rate: 5.0000e-04
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 105.9816 - mae: 3.6161 - val_loss: 26.2020 - val_mae: 2.3410 - learning_rate: 5.0000e-04
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 88.2747 - mae: 3.5281 - val_loss: 26.1348 - val_mae: 2.3251 - learning_rate: 5.0000e-04
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 95.3979 - mae: 3.5120 - val_loss: 26.0836 - val_mae: 2.3751 - learning_rate: 5.0000e-04
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 91.7773 - mae: 3.5756 - val_loss: 26.6624 - val_mae: 2.2305 - learning_rate: 5.0000e-04
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 93.4074 - mae: 3.4971 - val_loss: 26.2634 - val_mae: 2.2371 - learning_rate: 5.0000e-04
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 105.0790 - mae: 3.5035 - val_loss: 25.7349 - val_mae: 2.3192 - learning_rate: 5.0000e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 96.5781 - mae: 3.5177 - val_loss: 25.2815 - val_mae: 2.3087 - learning_rate: 5.0000e-04
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 94.0143 - mae: 3.5402 - val_loss: 25.4769 - val_mae: 2.2287 - learning_rate: 5.0000e-04
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 88.9586 - mae: 3.4440 - val_loss: 25.7968 - val_mae: 2.1945 - learning_rate: 5.0000e-04
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 98.6953 - mae: 3.5197 - val_loss: 25.7175 - val_mae: 2.2736 - learning_rate: 5.0000e-04
# Epoch 41/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 90.8042 - mae: 3.4236 - val_loss: 24.9560 - val_mae: 2.3178 - learning_rate: 5.0000e-04
# Epoch 42/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 87.6124 - mae: 3.4120 - val_loss: 25.5807 - val_mae: 2.1738 - learning_rate: 5.0000e-04
# Epoch 43/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 89.2577 - mae: 3.3411 - val_loss: 25.2134 - val_mae: 2.2153 - learning_rate: 5.0000e-04
# Epoch 44/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 92.2176 - mae: 3.4681 - val_loss: 24.4611 - val_mae: 2.2256 - learning_rate: 5.0000e-04
# Epoch 45/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 94.9740 - mae: 3.5374 - val_loss: 24.9820 - val_mae: 2.1777 - learning_rate: 5.0000e-04
# Epoch 46/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 85.9546 - mae: 3.4512 - val_loss: 25.9393 - val_mae: 2.1671 - learning_rate: 5.0000e-04
# Epoch 47/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 84.4437 - mae: 3.3557 - val_loss: 25.6240 - val_mae: 2.2463 - learning_rate: 5.0000e-04
# Epoch 48/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 85.9573 - mae: 3.3787 - val_loss: 24.8134 - val_mae: 2.1755 - learning_rate: 5.0000e-04
# Epoch 49/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 88.9088 - mae: 3.4554
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 88.7896 - mae: 3.4536 - val_loss: 25.0703 - val_mae: 2.2111 - learning_rate: 5.0000e-04
# Epoch 50/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 75.2174 - mae: 3.3183 - val_loss: 25.5290 - val_mae: 2.1760 - learning_rate: 2.5000e-04
# Epoch 51/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 88.1944 - mae: 3.3892 - val_loss: 25.0263 - val_mae: 2.1375 - learning_rate: 2.5000e-04
# Epoch 52/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 78.7873 - mae: 3.2273 - val_loss: 24.6834 - val_mae: 2.1996 - learning_rate: 2.5000e-04
# Epoch 53/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 76.9433 - mae: 3.2732 - val_loss: 25.4533 - val_mae: 2.1881 - learning_rate: 2.5000e-04
# Epoch 54/100
# 111/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 88.4702 - mae: 3.3732
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 86.8502 - mae: 3.3563 - val_loss: 24.9202 - val_mae: 2.2005 - learning_rate: 2.5000e-04

# %% [markdown]
# ### 4.3 Conv1D

# %%
conv1d_model = Sequential([
    Input(shape=(window_size, X_train_reg.shape[2])),
    Conv1D(64, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Conv1D(32, kernel_size=3, activation='relu', padding='same'),
    MaxPooling1D(pool_size=1),
    Dropout(0.3),
    Flatten(),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='linear')
])

conv1d_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

conv1d_callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1),
    ModelCheckpoint('conv1d_regressao.keras', save_best_only=True)
]

history_conv1d = conv1d_model.fit(
    X_train_reg, y_train_reg,
    validation_data=(X_val_reg, y_val_reg),
    epochs=100,
    batch_size=64,
    callbacks=conv1d_callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 363.0912 - mae: 6.0720 - val_loss: 52.7024 - val_mae: 2.8064 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 211.0855 - mae: 4.9180 - val_loss: 43.0078 - val_mae: 2.4461 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 170.0406 - mae: 4.6066 - val_loss: 37.3457 - val_mae: 2.3988 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 177.6678 - mae: 4.5422 - val_loss: 39.5764 - val_mae: 3.5841 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 136.8913 - mae: 4.1941 - val_loss: 53.9884 - val_mae: 4.5298 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 146.3598 - mae: 4.3125 - val_loss: 39.4515 - val_mae: 2.7702 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 149.3952 - mae: 4.2463 - val_loss: 42.1807 - val_mae: 2.5144 - learning_rate: 0.0010
# Epoch 8/100
# 104/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 175.8062 - mae: 4.2976
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 171.9316 - mae: 4.2744 - val_loss: 38.6345 - val_mae: 2.4462 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 134.9428 - mae: 4.1451 - val_loss: 32.7642 - val_mae: 2.5660 - learning_rate: 5.0000e-04
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 125.6475 - mae: 3.9981 - val_loss: 35.0483 - val_mae: 2.3367 - learning_rate: 5.0000e-04
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 120.0696 - mae: 3.8650 - val_loss: 34.5839 - val_mae: 2.3415 - learning_rate: 5.0000e-04
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 128.2213 - mae: 3.9642 - val_loss: 36.9356 - val_mae: 2.2977 - learning_rate: 5.0000e-04
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 115.1056 - mae: 3.7976 - val_loss: 34.0552 - val_mae: 2.2575 - learning_rate: 5.0000e-04
# Epoch 14/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 149.0445 - mae: 4.0793
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 148.4911 - mae: 4.0752 - val_loss: 35.8227 - val_mae: 2.2907 - learning_rate: 5.0000e-04
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 112.1067 - mae: 3.7617 - val_loss: 34.3386 - val_mae: 2.2863 - learning_rate: 2.5000e-04
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 113.9304 - mae: 3.7486 - val_loss: 32.6256 - val_mae: 2.3217 - learning_rate: 2.5000e-04
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 118.8066 - mae: 3.7568 - val_loss: 34.1578 - val_mae: 2.2183 - learning_rate: 2.5000e-04
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 123.8271 - mae: 3.9316 - val_loss: 34.0368 - val_mae: 2.2416 - learning_rate: 2.5000e-04
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 117.4793 - mae: 3.7833 - val_loss: 33.3529 - val_mae: 2.2666 - learning_rate: 2.5000e-04
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 133.7825 - mae: 3.9031 - val_loss: 31.8677 - val_mae: 2.3056 - learning_rate: 2.5000e-04
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 130.9400 - mae: 3.8967 - val_loss: 33.6325 - val_mae: 2.2280 - learning_rate: 2.5000e-04
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 130.0352 - mae: 3.8925 - val_loss: 33.2588 - val_mae: 2.2339 - learning_rate: 2.5000e-04
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 114.5066 - mae: 3.8819 - val_loss: 33.4916 - val_mae: 2.2189 - learning_rate: 2.5000e-04
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 127.3572 - mae: 3.7988 - val_loss: 33.6931 - val_mae: 2.2703 - learning_rate: 2.5000e-04
# Epoch 25/100
# 106/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 154.2846 - mae: 3.9818
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 149.0780 - mae: 3.9559 - val_loss: 33.6541 - val_mae: 2.2437 - learning_rate: 2.5000e-04
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 111.3093 - mae: 3.7127 - val_loss: 33.4178 - val_mae: 2.2731 - learning_rate: 1.2500e-04
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 104.9986 - mae: 3.7443 - val_loss: 33.1352 - val_mae: 2.2669 - learning_rate: 1.2500e-04
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 108.0965 - mae: 3.7580 - val_loss: 32.8500 - val_mae: 2.2186 - learning_rate: 1.2500e-04
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 100.9670 - mae: 3.6854 - val_loss: 32.1929 - val_mae: 2.2947 - learning_rate: 1.2500e-04
# Epoch 30/100
# 104/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 107.9621 - mae: 3.7421
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 106.6292 - mae: 3.7275 - val_loss: 32.7430 - val_mae: 2.2710 - learning_rate: 1.2500e-04

# %% [markdown]
# ### 4.4 Avaliação dos Modelos

# %%
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

def evaluate_regression_model(model, X, y, name):
    y_pred = model.predict(X).flatten()
    
    mae = mean_absolute_error(y, y_pred)
    rmse = root_mean_squared_error(y, y_pred)
    r2 = r2_score(y, y_pred)

    print(f"Modelo: {name}")
    print(f"MAE : {mae:.2f}")
    print(f"RMSE: {rmse:.2f}")
    print(f"R²  : {r2:.4f}")

    # Dispersão log
    plt.figure(figsize=(6, 6))
    plt.scatter(y, y_pred, alpha=0.5, color='royalblue')
    plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel("Casos Reais (log)")
    plt.ylabel("Casos Previstos (log)")
    plt.title(f"{name} - Dispersão Log")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return mae, rmse, r2

# Avaliação
lstm_metrics = evaluate_regression_model(lstm_model, X_test_reg, y_test_reg, "LSTM")
conv1d_metrics = evaluate_regression_model(conv1d_model, X_test_reg, y_test_reg, "Conv1D")
# Out:
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📌 LSTM
# MAE : 2.01
# RMSE: 4.71
# R²  : 0.5032
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 📌 Conv1D
# MAE : 2.07
# RMSE: 4.87
# R²  : 0.4700

# %% [markdown]
# ## 5 - Investiação da sensibilidade dos modelos

# %%
# %pip install shap --quiet

import shap
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Seleciona 500 amostras aleatórias do conjunto de teste (ou menos, se preferir)
n_samples = 500
idx = np.random.choice(len(X_test_reg), size=n_samples, replace=False)
X_sample = X_test_reg[idx]

# %%
# Converte a amostra para tensor
explainer_lstm = shap.DeepExplainer(lstm_model, tf.convert_to_tensor(X_sample))

# %%
# Calcula os valores SHAP para as amostras
shap_values = explainer_lstm.shap_values(X_sample)[0]  # índice 0 pois é univariado
# Out:
# ---------------------------------------------------------------------------
# StagingError                              Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Calcula os valores SHAP para as amostras
# ----> 2 shap_values = explainer_lstm.shap_values(X_sample)[0]  # índice 0 pois é univariado
#
# File c:\Users\User\anaconda3\envs\dengue_dl\Lib\site-packages\shap\explainers\_deep\__init__.py:164, in DeepExplainer.shap_values(self, X, ranked_outputs, output_rank_order, check_additivity)
#     120 def shap_values(self, X, ranked_outputs=None, output_rank_order="max", check_additivity=True):
#     121     """Return approximate SHAP values for the model applied to the data given by X.
#     122
#     123     Parameters
#    (...)    162
#     163     """
# --> 164     return self.explainer.shap_values(X, ranked_outputs, output_rank_order, check_additivity=check_additivity)
#
# File c:\Users\User\anaconda3\envs\dengue_dl\Lib\site-packages\shap\explainers\_deep\deep_tf.py:332, in TFDeep.shap_values(self, X, ranked_outputs, output_rank_order, check_additivity)
#     330 # run attribution computation graph
#     331 feature_ind = model_output_ranks[j, i]
# --> 332 sample_phis = self.run(self.phi_symbolic(feature_ind), self.model_inputs, joint_input)
#     334 # assign the attributions to the right part of the output arrays
#     335 for t in range(len(X)):
#
# File c:\Users\User\anaconda3\envs\dengue_dl\Lib\site-packages\shap\explainers\_deep\deep_tf.py:389, in TFDeep.run(self, out, model_inputs, X)
#     385         tf_execute.record_gradient = tf_backprop.record_gradient
#     387     return final_out
# --> 389 return self.execute_with_overridden_gradients(anon)
#
# File c:\Users\User\anaconda3\envs\dengue_dl\Lib\site-packages\shap\explainers\_deep\deep_tf.py:421, in TFDeep.execute_with_overridden_gradients(self, f)
#     419 # define the computation graph for the attribution values using a custom gradient-like computation
#     420 try:
# --> 421     out = f()
#     422 finally:
#     423     # reinstate the backpropagatable check
#     424     if hasattr(tf_gradients_impl, "_IsBackpropagatable"):
#
# File c:\Users\User\anaconda3\envs\dengue_dl\Lib\site-packages\shap\explainers\_deep\deep_tf.py:381, in TFDeep.run.<locals>.anon()
#     379     v = tf.constant(data, dtype=self.model_inputs[i].dtype)
#     380     inputs.append(v)
# --> 381 final_out = out(inputs)
#     382 try:
#     383     tf_execute.record_gradient = tf_backprop._record_gradient
#
# File c:\Users\User\anaconda3\envs\dengue_dl\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\User\anaconda3\envs\dengue_dl\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:52, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
# ---> 52     raise e.ag_error_metadata.to_exception(e)
#      53   else:
#      54     raise
#
# StagingError: in user code:
#
#     File "c:\Users\User\anaconda3\envs\dengue_dl\Lib\site-packages\shap\explainers\_deep\deep_tf.py", line 265, in grad_graph  *
#         x_grad = tape.gradient(out, shap_rAnD)
#
#     LookupError: gradient registry has no entry for: shap_TensorListStack
