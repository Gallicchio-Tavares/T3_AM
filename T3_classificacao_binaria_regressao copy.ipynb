# %% [markdown]
# <a id="top"></a>
# <div class="list-group" id="list-tab" role="tablist">
# <h1 class="list-group-item list-group-item-action active" data-toggle="list" style='background:#005097; border:0' role="tab" aria-controls="home"><center>APRENDIZADO DE MÁQUINA (GCC1932) - Trabalho 3</center></h1>
#
# - Nome completo: Bianca Gallicchio Tavares
# - [Link para vídeo](https://youtu.be/pR8AvE2IriM)

# %% [markdown]
# ## 0 - Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import tensorflow as tf
from tensorflow.keras import backend as K
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Conv1D, Dense, Dropout, Flatten, MaxPooling1D, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Configurações
plt.style.use('ggplot')
sns.set_palette("husl")
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 1 - Carregando o dataset

# %%
def load_and_analyze(data_path, feature_dict_path):
    """Carrega dados e realiza análise exploratória"""
    # Carregamento
    with open(data_path, 'rb') as f:
        X_train, y_train, X_val, y_val, X_test, y_test = pickle.load(f)
    
    feature_dict = pd.read_csv(feature_dict_path)
    
    # Análise de distribuição
    print("\nDistribuição dos Casos:")
    print(f"Total de casos (treino): {y_train.sum()}")
    print(f"Média semanal (treino): {y_train.mean():.2f}")
    print(f"Máximo em uma semana: {y_train.max()}")
    
    plt.figure(figsize=(10, 5))
    plt.hist(y_train, bins=50, alpha=0.7, label='Treino')
    plt.hist(y_val, bins=50, alpha=0.7, label='Validação')
    plt.hist(y_test, bins=50, alpha=0.7, label='Teste')
    plt.title('Distribuição dos Casos de Dengue')
    plt.legend()
    plt.show()
    
    return X_train, y_train, X_val, y_val, X_test, y_test, feature_dict

# %%
data_path = 'DATASETS/RJ_WEEKLY/dataset.pickle'
feature_dict_path = 'DATASETS/RJ_WEEKLY/feature_dictionary.csv'
X_train, y_train, X_val, y_val, X_test, y_test, feature_dict = load_and_analyze(data_path, feature_dict_path)
# Out:
# Distribuição dos Casos:
# Total de casos (treino): 47117
# Média semanal (treino): 0.20
# Máximo em uma semana: 337

# %% [markdown]
# ### Dicionário de Features

# %% [markdown]
# Este dicionário é gerado automaticamente durante a criação do dataset, baseado nas colunas do DataFrame final antes da conversão para NumPy.
#
# 1. **TEM_AVG**: Temperatura média diária (°C)
# 2. **TEM_MIN**: Temperatura mínima diária (°C)
# 3. **TEM_MAX**: Temperatura máxima diária (°C)
# 4. **RAIN**: Precipitação total diária (mm)
# 5. **RH_AVG**: Umidade relativa média do dia (%)
# 6. **RH_MIN**: Umidade relativa mínima do dia (%)
# 7. **RH_MAX**: Umidade relativa máxima do dia (%)
# 8. **IDEAL_TEMP**: Temperatura ideal para eclosão de ovos e amadurecimento do mosquito (°C)
# 9. **EXTREME_TEMP**: Temperatura nociva para o mosquito (°C)
# 10. **SIGNIFICANT_RAIN**: Chuva significativa capaz de criar novos criadouros (mm)
# 11. **EXTREME_RAIN**: Chuva extrema que remove ovos do ambiente (mm)
# 12. **TEMP_RANGE**: Amplitude térmica do dia (°C)
# 13. **WEEK_OF_YEAR**: Semana epidemiológica (1 a 52)
# 14. **TEM_AVG_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 15. **CASES_MM_7**: Número de casos reportados
# 16. **CASES_ACC_7**: Número de casos reportados
# 17. **RAIN_ACC_7**: Valor acumulado (soma ao longo do tempo)
# 18. **RAIN_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 19. **RH_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 20. **TEMP_RANGE_MM_7**: Amplitude térmica do dia (°C)
# 21. **TEM_AVG_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 22. **CASES_MM_14**: Número de casos reportados
# 23. **CASES_ACC_14**: Número de casos reportados
# 24. **RAIN_ACC_14**: Valor acumulado (soma ao longo do tempo)
# 25. **RAIN_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 26. **RH_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 27. **TEMP_RANGE_MM_14**: Amplitude térmica do dia (°C)
# 28. **TEM_AVG_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 29. **CASES_MM_21**: Número de casos reportados
# 30. **CASES_ACC_21**: Número de casos reportados
# 31. **RAIN_ACC_21**: Valor acumulado (soma ao longo do tempo)
# 32. **RAIN_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 33. **RH_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 34. **TEMP_RANGE_MM_21**: Amplitude térmica do dia (°C)
# 35. **TEM_AVG_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 36. **CASES_MM_28**: Número de casos reportados
# 37. **CASES_ACC_28**: Número de casos reportados
# 38. **RAIN_ACC_28**: Valor acumulado (soma ao longo do tempo)
# 39. **RAIN_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 40. **RH_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 41. **TEMP_RANGE_MM_28**: Amplitude térmica do dia (°C)
# 42. **CASES_LAG_1**: Número de casos reportados
# 43. **CASES_LAG_2**: Número de casos reportados
# 44. **CASES_LAG_3**: Número de casos reportados
# 45. **CASES_LAG_4**: Número de casos reportados
# 46. **CASES_LAG_5**: Número de casos reportados
# 47. **CASES_LAG_6**: Número de casos reportados

# %% [markdown]
# ## 2 - Análise Exploratória

# %%
# Carregando o dicionário de features para entender as variáveis
feature_dict = pd.read_csv('DATASETS/RJ_WEEKLY/feature_dictionary.csv')
print("\nDicionário de Variáveis:")
print(feature_dict)
# Out:
# Dicionário de Variáveis:
#     Index           Feature
# 0       0           TEM_AVG
# 1       1           TEM_MIN
# 2       2           TEM_MAX
# 3       3              RAIN
# 4       4            RH_AVG
# 5       5            RH_MIN
# 6       6            RH_MAX
# 7       7        CASES_MM_7
# 8       8       CASES_MM_14
# 9       9       CASES_MM_21
# 10     10       CASES_MM_28
# 11     11       CASES_ACC_7
# 12     12      CASES_ACC_14
# 13     13      CASES_ACC_21
# 14     14      CASES_ACC_28
# 15     15       CASES_LAG_1
# 16     16       CASES_LAG_2
# 17     17       CASES_LAG_3
# 18     18       CASES_LAG_4
# 19     19       CASES_LAG_5
# 20     20       CASES_LAG_6
# 21     21        IDEAL_TEMP
# 22     22      EXTREME_TEMP
# 23     23  SIGNIFICANT_RAIN
# 24     24      EXTREME_RAIN
# 25     25        TEMP_RANGE
# 26     26      WEEK_OF_YEAR
# 27     27      TEM_AVG_MM_7
# 28     28        RAIN_ACC_7
# 29     29         RAIN_MM_7
# 30     30           RH_MM_7
# 31     31   TEMP_RANGE_MM_7
# 32     32     TEM_AVG_MM_14
# 33     33       RAIN_ACC_14
# 34     34        RAIN_MM_14
# 35     35          RH_MM_14
# 36     36  TEMP_RANGE_MM_14
# 37     37     TEM_AVG_MM_21
# 38     38       RAIN_ACC_21
# 39     39        RAIN_MM_21
# 40     40          RH_MM_21
# 41     41  TEMP_RANGE_MM_21
# 42     42     TEM_AVG_MM_28
# 43     43       RAIN_ACC_28
# 44     44        RAIN_MM_28
# 45     45          RH_MM_28
# 46     46  TEMP_RANGE_MM_28

# %%
# Verificando a dimensionalidade dos dados
print("\nDimensionalidade dos dados:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Dimensionalidade dos dados:
# X_train shape: (235118, 47)
# y_train shape: (235118,)

# %% [markdown]
# O dataset é **altamente desbalanceado**, com a maioria das observações registrando **zero casos** de dengue.
# Essa característica é comum em contextos epidemiológicos onde a maioria dos dias/unidades não apresentam surtos.

# %%
# Estatísticas de distribuição de classes
n_total = len(y_train)
n_positive = np.sum(y_train > 0)
n_zero = n_total - n_positive
pct_positive = (n_positive / n_total) * 100

print(f"Total de amostras: {n_total}")
print(f"Com casos (>0): {n_positive} ({pct_positive:.2f}%)")
print(f"Sem casos (=0): {n_zero} ({100 - pct_positive:.2f}%)")
# Out:
# Total de amostras: 235118
# Com casos (>0): 7805 (3.32%)
# Sem casos (=0): 227313 (96.68%)

# %%
# Correlações com variáveis climáticas
cases_related_vars = [
    'CASES_MM_7', 'CASES_ACC_7', 'CASES_MM_14', 'CASES_ACC_14',
    'CASES_MM_21', 'CASES_ACC_21', 'CASES_MM_28', 'CASES_ACC_28',
    'CASES_LAG_1', 'CASES_LAG_2', 'CASES_LAG_3', 'CASES_LAG_4',
    'CASES_LAG_5', 'CASES_LAG_6'
]
climate_vars = [f for f in feature_dict['Feature'] if f not in cases_related_vars]

df_train_climate = pd.DataFrame(X_train, columns=feature_dict['Feature'])
df_train_climate = df_train_climate[climate_vars]
df_train_climate['Casos'] = y_train

corr_matrix_climate = df_train_climate.corr()

plt.figure(figsize=(12, 6))
corr_matrix_climate['Casos'].sort_values(ascending=False)[:-1].plot(kind='bar')
plt.title('Correlação entre Variáveis Climáticas e Casos de Dengue')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Mostrando as 10 variáveis climáticas mais correlacionadas
print("\nTop 10 variáveis CLIMÁTICAS mais correlacionadas com Casos de Dengue:")
print(corr_matrix_climate['Casos'].sort_values(ascending=False).head(11)[1:])  # Pula a correlação consigo mesmo

print("\nTop 10 variáveis CLIMÁTICAS mais negativamente correlacionadas com Casos de Dengue:")
print(corr_matrix_climate['Casos'].sort_values().head(10))
# Out:
# Top 10 variáveis CLIMÁTICAS mais correlacionadas com Casos de Dengue:
# Feature
# RAIN_ACC_21     0.032468
# RAIN_MM_21      0.032468
# RAIN_ACC_28     0.031881
# RAIN_MM_28      0.031881
# RAIN_MM_14      0.027074
# RAIN_ACC_14     0.027074
# RH_MM_7         0.018568
# RH_MM_14        0.016504
# RH_AVG          0.015392
# EXTREME_TEMP    0.014736
# Name: Casos, dtype: float64
#
# Top 10 variáveis CLIMÁTICAS mais negativamente correlacionadas com Casos de Dengue:
# Feature
# WEEK_OF_YEAR       -0.031065
# TEMP_RANGE_MM_7    -0.025737
# TEMP_RANGE_MM_14   -0.023960
# TEMP_RANGE         -0.017104
# TEM_MAX            -0.015629
# TEMP_RANGE_MM_21   -0.014926
# TEM_AVG            -0.003996
# TEMP_RANGE_MM_28   -0.003591
# SIGNIFICANT_RAIN   -0.002144
# TEM_MIN            -0.001036
# Name: Casos, dtype: float64

# %% [markdown]
# ## 3 - Classificação Binária

# %% [markdown]
# ### 3.1 Pré-processamento

# %%
# Transformando y em binário (1 = caso, 0 = sem caso)
y_train_bin = (y_train > 0).astype(int)
y_val_bin = (y_val > 0).astype(int)
y_test_bin = (y_test > 0).astype(int)

# %% [markdown]
# #### Criando janelas temporais

# %%
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(window_size, len(X)):
        X_seq.append(X[i-window_size:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

window_size = 14

X_train_seq, y_train_seq = create_sequences(X_train, y_train_bin, window_size)
X_val_seq, y_val_seq = create_sequences(X_val, y_val_bin, window_size)
X_test_seq, y_test_seq = create_sequences(X_test, y_test_bin, window_size)

# %% [markdown]
# #### Normalização

# %%
X_scaler = MinMaxScaler()

X_train_flat = X_train_seq.reshape(-1, X_train_seq.shape[2])
X_val_flat = X_val_seq.reshape(-1, X_val_seq.shape[2])
X_test_flat = X_test_seq.reshape(-1, X_test_seq.shape[2])

X_scaler.fit(X_train_flat)

X_train_norm = X_scaler.transform(X_train_flat).reshape(X_train_seq.shape)
X_val_norm = X_scaler.transform(X_val_flat).reshape(X_val_seq.shape)
X_test_norm = X_scaler.transform(X_test_flat).reshape(X_test_seq.shape)

# %% [markdown]
# ### 3.2 Modelo LSTM

# %%
lstm_model = Sequential([
    Input(shape=(window_size, X_train_norm.shape[2])),
    LSTM(64, return_sequences=False),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # Saída binária
])

lstm_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, verbose=1),
    ModelCheckpoint('melhor_lstm_classificacao.keras', save_best_only=True, monitor='val_loss')
]

# %%
history_lstm = lstm_model.fit(
    X_train_norm, y_train_seq,
    validation_data=(X_val_norm, y_val_seq),
    epochs=100,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - accuracy: 0.9667 - loss: 0.1410 - precision: 0.5037 - recall: 0.0744 - val_accuracy: 0.9659 - val_loss: 0.1184 - val_precision: 0.6714 - val_recall: 0.3140 - learning_rate: 0.0010
# Epoch 2/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9724 - loss: 0.0996 - precision: 0.7069 - recall: 0.2786 - val_accuracy: 0.9675 - val_loss: 0.1083 - val_precision: 0.7256 - val_recall: 0.3215 - learning_rate: 0.0010
# Epoch 3/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9735 - loss: 0.0922 - precision: 0.7253 - recall: 0.3191 - val_accuracy: 0.9678 - val_loss: 0.1064 - val_precision: 0.7424 - val_recall: 0.3169 - learning_rate: 0.0010
# Epoch 4/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9736 - loss: 0.0886 - precision: 0.7205 - recall: 0.3257 - val_accuracy: 0.9681 - val_loss: 0.1084 - val_precision: 0.7440 - val_recall: 0.3268 - learning_rate: 0.0010
# Epoch 5/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9736 - loss: 0.0871 - precision: 0.7278 - recall: 0.3177 - val_accuracy: 0.9680 - val_loss: 0.1065 - val_precision: 0.7425 - val_recall: 0.3246 - learning_rate: 0.0010
# Epoch 6/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9738 - loss: 0.0860 - precision: 0.7282 - recall: 0.3265 - val_accuracy: 0.9682 - val_loss: 0.1071 - val_precision: 0.7552 - val_recall: 0.3205 - learning_rate: 0.0010
# Epoch 7/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9742 - loss: 0.0849 - precision: 0.7394 - recall: 0.3347 - val_accuracy: 0.9680 - val_loss: 0.1078 - val_precision: 0.7674 - val_recall: 0.3048 - learning_rate: 0.0010
# Epoch 8/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9738 - loss: 0.0843 - precision: 0.7301 - recall: 0.3267 - val_accuracy: 0.9680 - val_loss: 0.1044 - val_precision: 0.7771 - val_recall: 0.2966 - learning_rate: 0.0010
# Epoch 9/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9742 - loss: 0.0839 - precision: 0.7387 - recall: 0.3386 - val_accuracy: 0.9681 - val_loss: 0.1014 - val_precision: 0.7720 - val_recall: 0.3063 - learning_rate: 0.0010
# Epoch 10/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9743 - loss: 0.0833 - precision: 0.7412 - recall: 0.3409 - val_accuracy: 0.9680 - val_loss: 0.1024 - val_precision: 0.7722 - val_recall: 0.3008 - learning_rate: 0.0010
# Epoch 11/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9742 - loss: 0.0832 - precision: 0.7462 - recall: 0.3324 - val_accuracy: 0.9680 - val_loss: 0.1019 - val_precision: 0.7669 - val_recall: 0.3071 - learning_rate: 0.0010
# Epoch 12/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9743 - loss: 0.0819 - precision: 0.7393 - recall: 0.3403 - val_accuracy: 0.9677 - val_loss: 0.1013 - val_precision: 0.7772 - val_recall: 0.2885 - learning_rate: 0.0010
# Epoch 13/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9744 - loss: 0.0817 - precision: 0.7482 - recall: 0.3359 - val_accuracy: 0.9680 - val_loss: 0.1013 - val_precision: 0.7712 - val_recall: 0.3031 - learning_rate: 0.0010
# Epoch 14/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9744 - loss: 0.0815 - precision: 0.7503 - recall: 0.3385 - val_accuracy: 0.9677 - val_loss: 0.1047 - val_precision: 0.7835 - val_recall: 0.2842 - learning_rate: 0.0010
# Epoch 15/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9743 - loss: 0.0810 - precision: 0.7416 - recall: 0.3414 - val_accuracy: 0.9680 - val_loss: 0.1026 - val_precision: 0.7769 - val_recall: 0.2986 - learning_rate: 0.0010
# Epoch 16/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9746 - loss: 0.0806 - precision: 0.7452 - recall: 0.3499 - val_accuracy: 0.9681 - val_loss: 0.1026 - val_precision: 0.7727 - val_recall: 0.3039 - learning_rate: 0.0010
# Epoch 17/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9747 - loss: 0.0804 - precision: 0.7522 - recall: 0.3457
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9747 - loss: 0.0804 - precision: 0.7522 - recall: 0.3457 - val_accuracy: 0.9680 - val_loss: 0.1022 - val_precision: 0.7849 - val_recall: 0.2933 - learning_rate: 0.0010
# Epoch 18/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9748 - loss: 0.0790 - precision: 0.7529 - recall: 0.3537 - val_accuracy: 0.9680 - val_loss: 0.1021 - val_precision: 0.7644 - val_recall: 0.3092 - learning_rate: 5.0000e-04
# Epoch 19/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9749 - loss: 0.0785 - precision: 0.7487 - recall: 0.3619 - val_accuracy: 0.9681 - val_loss: 0.1016 - val_precision: 0.7618 - val_recall: 0.3131 - learning_rate: 5.0000e-04
# Epoch 20/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9747 - loss: 0.0784 - precision: 0.7451 - recall: 0.3552 - val_accuracy: 0.9679 - val_loss: 0.1022 - val_precision: 0.7880 - val_recall: 0.2876 - learning_rate: 5.0000e-04
# Epoch 21/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9751 - loss: 0.0780 - precision: 0.7586 - recall: 0.3587 - val_accuracy: 0.9680 - val_loss: 0.1019 - val_precision: 0.7925 - val_recall: 0.2894 - learning_rate: 5.0000e-04
# Epoch 22/100
# 3665/3674 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9753 - loss: 0.0778 - precision: 0.7641 - recall: 0.3627
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9753 - loss: 0.0778 - precision: 0.7641 - recall: 0.3627 - val_accuracy: 0.9679 - val_loss: 0.1027 - val_precision: 0.7820 - val_recall: 0.2907 - learning_rate: 5.0000e-04
# Epoch 23/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9749 - loss: 0.0774 - precision: 0.7504 - recall: 0.3593 - val_accuracy: 0.9680 - val_loss: 0.1023 - val_precision: 0.7821 - val_recall: 0.2954 - learning_rate: 2.5000e-04

# %% [markdown]
# ### 3.3 Avaliação do Modelo

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

y_pred_probs = lstm_model.predict(X_test_norm).flatten()
y_pred_labels = (y_pred_probs >= 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test_seq, y_pred_labels))

cm = confusion_matrix(y_test_seq, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Sem casos', 'Com casos'])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM Classificação")
plt.grid(False)
plt.show()
# Out:
# 2852/2852 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     82271
#            1       0.76      0.33      0.46      8990
#
#     accuracy                           0.92     91261
#    macro avg       0.85      0.66      0.71     91261
# weighted avg       0.91      0.92      0.91     91261

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    roc_curve,
    precision_recall_curve,
    balanced_accuracy_score,
    f1_score
)

# %%
# AUC-ROC
roc_auc = roc_auc_score(y_test_seq, y_pred_probs)

# AUC-PR
pr_auc = average_precision_score(y_test_seq, y_pred_probs)

# Balanced Accuracy
bal_acc = balanced_accuracy_score(y_test_seq, y_pred_labels)

# F1 Score
f1 = f1_score(y_test_seq, y_pred_labels)

print(f"\nMétricas adicionais:")
print(f"AUC-ROC: {roc_auc:.4f}")
print(f"AUC-PR : {pr_auc:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Balanced Accuracy: {bal_acc:.4f}")
# Out:
# Métricas adicionais:
# AUC-ROC: 0.9014
# AUC-PR : 0.6017
# F1 Score: 0.4615
# Balanced Accuracy: 0.6599

# %%
# ROC Curve
fpr, tpr, _ = roc_curve(y_test_seq, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], 'k--', label="Random")
plt.xlabel("FPR (1 - Especificidade)")
plt.ylabel("TPR (Sensibilidade)")
plt.title("Curva ROC")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test_seq, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(recall, precision, label=f"AP = {pr_auc:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Curva Precision-Recall")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Resumo Crítico
#
# - O modelo é conservador: prefere errar por omissão (não prever dengue quando tem) do que por alarme falso.
#
# - Ele é muito bom em evitar falsos positivos, mas perde muitos casos reais, o que pode ser crítico em contexto de saúde pública.
#
# - O AUC-ROC alto indica que o modelo poderia ser calibrado para melhorar o recall, ajustando o threshold de decisão (por padrão é 0.5).

# %% [markdown]
# ## 4 - Regressão

# %% [markdown]
# ### 4.1 Pré-processamento

# %%
# PRE PROCESSAMENTO

# Função para criar janelas temporais
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(window_size, len(X)):
        X_seq.append(X[i-window_size:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

# Definindo janela
window_size = 7

# Criando janelas
X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size)
X_val_seq, y_val_seq = create_sequences(X_val, y_val, window_size)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size)

# Normalização
X_scaler = MinMaxScaler()
X_train_flat = X_train_seq.reshape(-1, X_train_seq.shape[2])
X_val_flat = X_val_seq.reshape(-1, X_val_seq.shape[2])
X_test_flat = X_test_seq.reshape(-1, X_test_seq.shape[2])

X_scaler.fit(X_train_flat)
X_train_norm = X_scaler.transform(X_train_flat).reshape(X_train_seq.shape)
X_val_norm = X_scaler.transform(X_val_flat).reshape(X_val_seq.shape)
X_test_norm = X_scaler.transform(X_test_flat).reshape(X_test_seq.shape)

# Filtrar apenas alvos com casos > 0
y_train_real = y_train[window_size:]
y_val_real = y_val[window_size:]
y_test_real = y_test[window_size:]

mask_train = y_train_real > 0
mask_val = y_val_real > 0
mask_test = y_test_real > 0

X_train_reg = X_train_norm[mask_train]
y_train_reg = y_train_real[mask_train]
X_val_reg = X_val_norm[mask_val]
y_val_reg = y_val_real[mask_val]
X_test_reg = X_test_norm[mask_test]
y_test_reg = y_test_real[mask_test]

# %% [markdown]
# ### 4.2 LSTM

# %%
# Construção
lstm_model = Sequential([
    Input(shape=(window_size, X_train_reg.shape[2])),
    LSTM(64, return_sequences=False),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='linear')
])

lstm_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Callbacks
lstm_callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1),
    ModelCheckpoint('lstm_regressao.keras', save_best_only=True)
]

# Treinamento
history_lstm = lstm_model.fit(
    X_train_reg, y_train_reg,
    validation_data=(X_val_reg, y_val_reg),
    epochs=100,
    batch_size=64,
    callbacks=lstm_callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 434.3659 - mae: 6.4720 - val_loss: 43.1524 - val_mae: 3.3180 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 355.9542 - mae: 5.8233 - val_loss: 42.8799 - val_mae: 2.5592 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 266.9033 - mae: 5.0754 - val_loss: 39.6505 - val_mae: 3.0321 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 219.8015 - mae: 4.7027 - val_loss: 39.8879 - val_mae: 2.9034 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 182.9860 - mae: 4.3673 - val_loss: 40.2154 - val_mae: 2.9478 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 162.1740 - mae: 4.2305 - val_loss: 37.6269 - val_mae: 2.5243 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 155.7069 - mae: 4.1192 - val_loss: 33.2885 - val_mae: 2.3115 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 135.9382 - mae: 3.9831 - val_loss: 34.4664 - val_mae: 2.4622 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 126.7267 - mae: 3.9114 - val_loss: 39.0398 - val_mae: 2.4012 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 131.1493 - mae: 3.9368 - val_loss: 34.5876 - val_mae: 2.3612 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 122.7502 - mae: 3.8974 - val_loss: 34.9062 - val_mae: 2.4674 - learning_rate: 0.0010
# Epoch 12/100
# 105/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 130.3847 - mae: 3.9185
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 129.1616 - mae: 3.9001 - val_loss: 34.9886 - val_mae: 2.3364 - learning_rate: 0.0010
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 117.0204 - mae: 3.7714 - val_loss: 31.9879 - val_mae: 2.2400 - learning_rate: 5.0000e-04
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 112.7327 - mae: 3.7174 - val_loss: 30.8675 - val_mae: 2.2818 - learning_rate: 5.0000e-04
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 107.0625 - mae: 3.6728 - val_loss: 31.0836 - val_mae: 2.2749 - learning_rate: 5.0000e-04
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 115.6400 - mae: 3.7790 - val_loss: 31.3108 - val_mae: 2.2506 - learning_rate: 5.0000e-04
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 103.8072 - mae: 3.6911 - val_loss: 31.6463 - val_mae: 2.2655 - learning_rate: 5.0000e-04
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 114.2645 - mae: 3.7785 - val_loss: 29.9649 - val_mae: 2.2632 - learning_rate: 5.0000e-04
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 121.0412 - mae: 3.8259 - val_loss: 29.8960 - val_mae: 2.2055 - learning_rate: 5.0000e-04
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 108.7221 - mae: 3.6783 - val_loss: 29.9828 - val_mae: 2.2345 - learning_rate: 5.0000e-04
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 119.6320 - mae: 3.7806 - val_loss: 29.6711 - val_mae: 2.2195 - learning_rate: 5.0000e-04
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 103.0387 - mae: 3.6914 - val_loss: 29.5399 - val_mae: 2.2024 - learning_rate: 5.0000e-04
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 107.4140 - mae: 3.6988 - val_loss: 29.0811 - val_mae: 2.2604 - learning_rate: 5.0000e-04
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 103.7105 - mae: 3.7015 - val_loss: 29.3339 - val_mae: 2.2619 - learning_rate: 5.0000e-04
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 104.7175 - mae: 3.6568 - val_loss: 28.8862 - val_mae: 2.2389 - learning_rate: 5.0000e-04
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 113.2049 - mae: 3.7445 - val_loss: 29.6889 - val_mae: 2.1876 - learning_rate: 5.0000e-04
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 93.4614 - mae: 3.6079 - val_loss: 28.4848 - val_mae: 2.2305 - learning_rate: 5.0000e-04
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 102.5565 - mae: 3.6621 - val_loss: 30.2406 - val_mae: 2.2022 - learning_rate: 5.0000e-04
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 105.0626 - mae: 3.6040 - val_loss: 29.4757 - val_mae: 2.1845 - learning_rate: 5.0000e-04
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 113.8055 - mae: 3.6804 - val_loss: 28.0846 - val_mae: 2.2035 - learning_rate: 5.0000e-04
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 106.7498 - mae: 3.6505 - val_loss: 28.5622 - val_mae: 2.2379 - learning_rate: 5.0000e-04
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 96.0621 - mae: 3.5843 - val_loss: 28.9651 - val_mae: 2.2313 - learning_rate: 5.0000e-04
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 97.6674 - mae: 3.6044 - val_loss: 28.0414 - val_mae: 2.2027 - learning_rate: 5.0000e-04
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 101.7497 - mae: 3.5707 - val_loss: 28.0820 - val_mae: 2.1999 - learning_rate: 5.0000e-04
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 94.4606 - mae: 3.5023 - val_loss: 27.9988 - val_mae: 2.1608 - learning_rate: 5.0000e-04
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 94.5476 - mae: 3.5822 - val_loss: 27.8894 - val_mae: 2.1792 - learning_rate: 5.0000e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 93.3525 - mae: 3.5611 - val_loss: 27.7208 - val_mae: 2.1747 - learning_rate: 5.0000e-04
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 101.4922 - mae: 3.6465 - val_loss: 28.3216 - val_mae: 2.2071 - learning_rate: 5.0000e-04
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 103.4628 - mae: 3.5909 - val_loss: 27.5680 - val_mae: 2.2461 - learning_rate: 5.0000e-04
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 92.0785 - mae: 3.5538 - val_loss: 27.8249 - val_mae: 2.1879 - learning_rate: 5.0000e-04
# Epoch 41/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 99.7684 - mae: 3.5497 - val_loss: 27.2592 - val_mae: 2.2441 - learning_rate: 5.0000e-04
# Epoch 42/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 97.3920 - mae: 3.5757 - val_loss: 27.4051 - val_mae: 2.2090 - learning_rate: 5.0000e-04
# Epoch 43/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 101.4106 - mae: 3.6132 - val_loss: 27.8960 - val_mae: 2.1761 - learning_rate: 5.0000e-04
# Epoch 44/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 98.5763 - mae: 3.5992 - val_loss: 27.1331 - val_mae: 2.1924 - learning_rate: 5.0000e-04
# Epoch 45/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 95.0479 - mae: 3.5727 - val_loss: 28.3649 - val_mae: 2.1691 - learning_rate: 5.0000e-04
# Epoch 46/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 90.9121 - mae: 3.4414 - val_loss: 27.3409 - val_mae: 2.1923 - learning_rate: 5.0000e-04
# Epoch 47/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 92.7490 - mae: 3.4773 - val_loss: 26.4326 - val_mae: 2.1480 - learning_rate: 5.0000e-04
# Epoch 48/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 87.4158 - mae: 3.4744 - val_loss: 27.0421 - val_mae: 2.2653 - learning_rate: 5.0000e-04
# Epoch 49/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 78.1304 - mae: 3.4040 - val_loss: 27.7335 - val_mae: 2.1894 - learning_rate: 5.0000e-04
# Epoch 50/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 88.8737 - mae: 3.4856 - val_loss: 27.0445 - val_mae: 2.1779 - learning_rate: 5.0000e-04
# Epoch 51/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 89.6642 - mae: 3.5002 - val_loss: 26.9652 - val_mae: 2.1487 - learning_rate: 5.0000e-04
# Epoch 52/100
# 108/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98.0909 - mae: 3.5134
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 96.1620 - mae: 3.4911 - val_loss: 27.5902 - val_mae: 2.1819 - learning_rate: 5.0000e-04
# Epoch 53/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 88.6142 - mae: 3.3879 - val_loss: 26.2590 - val_mae: 2.1346 - learning_rate: 2.5000e-04
# Epoch 54/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 78.1549 - mae: 3.3084 - val_loss: 26.8557 - val_mae: 2.1341 - learning_rate: 2.5000e-04
# Epoch 55/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 87.4652 - mae: 3.4106 - val_loss: 26.6752 - val_mae: 2.1565 - learning_rate: 2.5000e-04
# Epoch 56/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 86.7537 - mae: 3.3865 - val_loss: 26.6934 - val_mae: 2.1546 - learning_rate: 2.5000e-04
# Epoch 57/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 87.0178 - mae: 3.4068 - val_loss: 26.6839 - val_mae: 2.1509 - learning_rate: 2.5000e-04
# Epoch 58/100
# 106/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93.3868 - mae: 3.4588
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 91.1540 - mae: 3.4327 - val_loss: 27.0325 - val_mae: 2.1432 - learning_rate: 2.5000e-04
# Epoch 59/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 80.6757 - mae: 3.3293 - val_loss: 26.4107 - val_mae: 2.1412 - learning_rate: 1.2500e-04
# Epoch 60/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 84.3788 - mae: 3.3176 - val_loss: 26.8225 - val_mae: 2.1409 - learning_rate: 1.2500e-04
# Epoch 61/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 77.2744 - mae: 3.2885 - val_loss: 26.4728 - val_mae: 2.1403 - learning_rate: 1.2500e-04
# Epoch 62/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 86.9530 - mae: 3.2915 - val_loss: 26.6273 - val_mae: 2.1334 - learning_rate: 1.2500e-04
# Epoch 63/100
# 109/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104.7013 - mae: 3.4380
# Epoch 63: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 101.9655 - mae: 3.4156 - val_loss: 26.3668 - val_mae: 2.1501 - learning_rate: 1.2500e-04

# %% [markdown]
# ### 4.3 Conv1D

# %%
conv1d_model = Sequential([
    Input(shape=(window_size, X_train_reg.shape[2])),
    Conv1D(64, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Conv1D(32, kernel_size=3, activation='relu', padding='same'),
    MaxPooling1D(pool_size=1),
    Dropout(0.3),
    Flatten(),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='linear')
])

conv1d_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

conv1d_callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1),
    ModelCheckpoint('conv1d_regressao.keras', save_best_only=True)
]

history_conv1d = conv1d_model.fit(
    X_train_reg, y_train_reg,
    validation_data=(X_val_reg, y_val_reg),
    epochs=100,
    batch_size=64,
    callbacks=conv1d_callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 392.9553 - mae: 5.9544 - val_loss: 51.2057 - val_mae: 2.7863 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 211.2595 - mae: 4.9065 - val_loss: 46.6104 - val_mae: 2.5721 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 166.2990 - mae: 4.4850 - val_loss: 45.6488 - val_mae: 2.5688 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 161.4340 - mae: 4.2944 - val_loss: 42.7933 - val_mae: 2.4251 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 146.3328 - mae: 4.1665 - val_loss: 39.7025 - val_mae: 2.4101 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 141.0794 - mae: 4.1455 - val_loss: 40.1219 - val_mae: 2.5781 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 138.1954 - mae: 4.0375 - val_loss: 39.6248 - val_mae: 2.3641 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 156.8328 - mae: 4.1924 - val_loss: 36.6728 - val_mae: 2.5901 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 137.8235 - mae: 4.0892 - val_loss: 37.5393 - val_mae: 2.7530 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 123.4787 - mae: 3.9626 - val_loss: 38.7762 - val_mae: 2.3307 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 139.1212 - mae: 4.1422 - val_loss: 37.1182 - val_mae: 2.4995 - learning_rate: 0.0010
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 151.2398 - mae: 4.1252 - val_loss: 37.5815 - val_mae: 2.3574 - learning_rate: 0.0010
# Epoch 13/100
# 105/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 151.4137 - mae: 4.1554
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 148.6807 - mae: 4.1313 - val_loss: 39.2152 - val_mae: 2.3513 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 123.1299 - mae: 3.9520 - val_loss: 34.6083 - val_mae: 2.2871 - learning_rate: 5.0000e-04
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 136.0641 - mae: 3.9429 - val_loss: 37.0314 - val_mae: 2.2776 - learning_rate: 5.0000e-04
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 122.3809 - mae: 3.8904 - val_loss: 35.0795 - val_mae: 2.2736 - learning_rate: 5.0000e-04
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 142.1078 - mae: 4.0363 - val_loss: 37.7462 - val_mae: 2.3042 - learning_rate: 5.0000e-04
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 134.1594 - mae: 3.9491 - val_loss: 36.4950 - val_mae: 2.2896 - learning_rate: 5.0000e-04
# Epoch 19/100
# 109/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 123.5907 - mae: 3.9134
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 122.4446 - mae: 3.9032 - val_loss: 35.4335 - val_mae: 2.2910 - learning_rate: 5.0000e-04
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 126.9282 - mae: 3.7860 - val_loss: 34.8418 - val_mae: 2.3068 - learning_rate: 2.5000e-04
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 121.6537 - mae: 3.8105 - val_loss: 34.3527 - val_mae: 2.2788 - learning_rate: 2.5000e-04
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 117.0019 - mae: 3.8230 - val_loss: 33.4451 - val_mae: 2.3114 - learning_rate: 2.5000e-04
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 123.4369 - mae: 3.8160 - val_loss: 36.2042 - val_mae: 2.3151 - learning_rate: 2.5000e-04
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 117.3576 - mae: 3.7943 - val_loss: 34.3618 - val_mae: 2.3097 - learning_rate: 2.5000e-04
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 114.5055 - mae: 3.8170 - val_loss: 35.3491 - val_mae: 2.2865 - learning_rate: 2.5000e-04
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 118.0756 - mae: 3.7788 - val_loss: 34.5567 - val_mae: 2.2881 - learning_rate: 2.5000e-04
# Epoch 27/100
# 112/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 117.0170 - mae: 3.7682
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 116.4350 - mae: 3.7651 - val_loss: 34.2896 - val_mae: 2.3002 - learning_rate: 2.5000e-04
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 115.2937 - mae: 3.7804 - val_loss: 34.4365 - val_mae: 2.3233 - learning_rate: 1.2500e-04
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 112.8555 - mae: 3.7104 - val_loss: 34.0613 - val_mae: 2.3046 - learning_rate: 1.2500e-04
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112.8020 - mae: 3.8335 - val_loss: 34.6648 - val_mae: 2.3134 - learning_rate: 1.2500e-04
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 113.3310 - mae: 3.7648 - val_loss: 35.0197 - val_mae: 2.3041 - learning_rate: 1.2500e-04
# Epoch 32/100
# 100/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 111.0113 - mae: 3.6915
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 108.9960 - mae: 3.6843 - val_loss: 34.6452 - val_mae: 2.3088 - learning_rate: 1.2500e-04

# %% [markdown]
# ### 4.4 Avaliação dos Modelos

# %%
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

def evaluate_regression_model(model, X, y, name):
    y_pred = model.predict(X).flatten()
    
    mae = mean_absolute_error(y, y_pred)
    rmse = root_mean_squared_error(y, y_pred)
    r2 = r2_score(y, y_pred)

    print(f"Modelo: {name}")
    print(f"MAE : {mae:.2f}")
    print(f"RMSE: {rmse:.2f}")
    print(f"R²  : {r2:.4f}")

    # Dispersão log
    plt.figure(figsize=(6, 6))
    plt.scatter(y, y_pred, alpha=0.5, color='royalblue')
    plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel("Casos Reais (log)")
    plt.ylabel("Casos Previstos (log)")
    plt.title(f"{name} - Dispersão Log")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return mae, rmse, r2

# Avaliação
lstm_metrics = evaluate_regression_model(lstm_model, X_test_reg, y_test_reg, "LSTM")
conv1d_metrics = evaluate_regression_model(conv1d_model, X_test_reg, y_test_reg, "Conv1D")
# Out:
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Modelo: LSTM
# MAE : 1.97
# RMSE: 4.80
# R²  : 0.4847
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Modelo: Conv1D
# MAE : 2.13
# RMSE: 5.01
# R²  : 0.4378

# %% [markdown]
# ## 5 - Investiação da sensibilidade dos modelos
