# %% [markdown]
# <a id="top"></a>
# <div class="list-group" id="list-tab" role="tablist">
# <h1 class="list-group-item list-group-item-action active" data-toggle="list" style='background:#005097; border:0' role="tab" aria-controls="home"><center>APRENDIZADO DE MÁQUINA (GCC1932) - Trabalho 3</center></h1>
#
# - Nome completo: Bianca Gallicchio Tavares
# - [Link para vídeo](https://youtu.be/pR8AvE2IriM)

# %% [markdown]
# ## 0 - Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import tensorflow as tf
from tensorflow.keras import backend as K
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Conv1D, Dense, Dropout, Flatten, MaxPooling1D, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Configurações
plt.style.use('ggplot')
sns.set_palette("husl")
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 1 - Carregando o dataset

# %%
def load_and_analyze(data_path, feature_dict_path):
    """Carrega dados e realiza análise exploratória"""
    # Carregamento
    with open(data_path, 'rb') as f:
        X_train, y_train, X_val, y_val, X_test, y_test = pickle.load(f)
    
    feature_dict = pd.read_csv(feature_dict_path)
    
    # Análise de distribuição
    print("\nDistribuição dos Casos:")
    print(f"Total de casos (treino): {y_train.sum()}")
    print(f"Média semanal (treino): {y_train.mean():.2f}")
    print(f"Máximo em uma semana: {y_train.max()}")
    
    plt.figure(figsize=(10, 5))
    plt.hist(y_train, bins=50, alpha=0.7, label='Treino')
    plt.hist(y_val, bins=50, alpha=0.7, label='Validação')
    plt.hist(y_test, bins=50, alpha=0.7, label='Teste')
    plt.title('Distribuição dos Casos de Dengue')
    plt.legend()
    plt.show()
    
    return X_train, y_train, X_val, y_val, X_test, y_test, feature_dict

# %%
data_path = 'DATASETS/RJ_WEEKLY/dataset.pickle'
feature_dict_path = 'DATASETS/RJ_WEEKLY/feature_dictionary.csv'
X_train, y_train, X_val, y_val, X_test, y_test, feature_dict = load_and_analyze(data_path, feature_dict_path)
# Out:
# Distribuição dos Casos:
# Total de casos (treino): 47117
# Média semanal (treino): 0.20
# Máximo em uma semana: 337

# %% [markdown]
# ### Dicionário de Features

# %% [markdown]
# Este dicionário é gerado automaticamente durante a criação do dataset, baseado nas colunas do DataFrame final antes da conversão para NumPy.
#
# 1. **TEM_AVG**: Temperatura média diária (°C)
# 2. **TEM_MIN**: Temperatura mínima diária (°C)
# 3. **TEM_MAX**: Temperatura máxima diária (°C)
# 4. **RAIN**: Precipitação total diária (mm)
# 5. **RH_AVG**: Umidade relativa média do dia (%)
# 6. **RH_MIN**: Umidade relativa mínima do dia (%)
# 7. **RH_MAX**: Umidade relativa máxima do dia (%)
# 8. **IDEAL_TEMP**: Temperatura ideal para eclosão de ovos e amadurecimento do mosquito (°C)
# 9. **EXTREME_TEMP**: Temperatura nociva para o mosquito (°C)
# 10. **SIGNIFICANT_RAIN**: Chuva significativa capaz de criar novos criadouros (mm)
# 11. **EXTREME_RAIN**: Chuva extrema que remove ovos do ambiente (mm)
# 12. **TEMP_RANGE**: Amplitude térmica do dia (°C)
# 13. **WEEK_OF_YEAR**: Semana epidemiológica (1 a 52)
# 14. **TEM_AVG_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 15. **CASES_MM_7**: Número de casos reportados
# 16. **CASES_ACC_7**: Número de casos reportados
# 17. **RAIN_ACC_7**: Valor acumulado (soma ao longo do tempo)
# 18. **RAIN_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 19. **RH_MM_7**: Média móvel (ex: suavização de valores anteriores)
# 20. **TEMP_RANGE_MM_7**: Amplitude térmica do dia (°C)
# 21. **TEM_AVG_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 22. **CASES_MM_14**: Número de casos reportados
# 23. **CASES_ACC_14**: Número de casos reportados
# 24. **RAIN_ACC_14**: Valor acumulado (soma ao longo do tempo)
# 25. **RAIN_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 26. **RH_MM_14**: Média móvel (ex: suavização de valores anteriores)
# 27. **TEMP_RANGE_MM_14**: Amplitude térmica do dia (°C)
# 28. **TEM_AVG_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 29. **CASES_MM_21**: Número de casos reportados
# 30. **CASES_ACC_21**: Número de casos reportados
# 31. **RAIN_ACC_21**: Valor acumulado (soma ao longo do tempo)
# 32. **RAIN_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 33. **RH_MM_21**: Média móvel (ex: suavização de valores anteriores)
# 34. **TEMP_RANGE_MM_21**: Amplitude térmica do dia (°C)
# 35. **TEM_AVG_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 36. **CASES_MM_28**: Número de casos reportados
# 37. **CASES_ACC_28**: Número de casos reportados
# 38. **RAIN_ACC_28**: Valor acumulado (soma ao longo do tempo)
# 39. **RAIN_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 40. **RH_MM_28**: Média móvel (ex: suavização de valores anteriores)
# 41. **TEMP_RANGE_MM_28**: Amplitude térmica do dia (°C)
# 42. **CASES_LAG_1**: Número de casos reportados
# 43. **CASES_LAG_2**: Número de casos reportados
# 44. **CASES_LAG_3**: Número de casos reportados
# 45. **CASES_LAG_4**: Número de casos reportados
# 46. **CASES_LAG_5**: Número de casos reportados
# 47. **CASES_LAG_6**: Número de casos reportados

# %% [markdown]
# ## 2 - Análise Exploratória

# %%
# Carregando o dicionário de features para entender as variáveis
feature_dict = pd.read_csv('DATASETS/RJ_WEEKLY/feature_dictionary.csv')
print("\nDicionário de Variáveis:")
print(feature_dict)
# Out:
# Dicionário de Variáveis:
#     Index           Feature
# 0       0           TEM_AVG
# 1       1           TEM_MIN
# 2       2           TEM_MAX
# 3       3              RAIN
# 4       4            RH_AVG
# 5       5            RH_MIN
# 6       6            RH_MAX
# 7       7        CASES_MM_7
# 8       8       CASES_MM_14
# 9       9       CASES_MM_21
# 10     10       CASES_MM_28
# 11     11       CASES_ACC_7
# 12     12      CASES_ACC_14
# 13     13      CASES_ACC_21
# 14     14      CASES_ACC_28
# 15     15       CASES_LAG_1
# 16     16       CASES_LAG_2
# 17     17       CASES_LAG_3
# 18     18       CASES_LAG_4
# 19     19       CASES_LAG_5
# 20     20       CASES_LAG_6
# 21     21        IDEAL_TEMP
# 22     22      EXTREME_TEMP
# 23     23  SIGNIFICANT_RAIN
# 24     24      EXTREME_RAIN
# 25     25        TEMP_RANGE
# 26     26      WEEK_OF_YEAR
# 27     27      TEM_AVG_MM_7
# 28     28        RAIN_ACC_7
# 29     29         RAIN_MM_7
# 30     30           RH_MM_7
# 31     31   TEMP_RANGE_MM_7
# 32     32     TEM_AVG_MM_14
# 33     33       RAIN_ACC_14
# 34     34        RAIN_MM_14
# 35     35          RH_MM_14
# 36     36  TEMP_RANGE_MM_14
# 37     37     TEM_AVG_MM_21
# 38     38       RAIN_ACC_21
# 39     39        RAIN_MM_21
# 40     40          RH_MM_21
# 41     41  TEMP_RANGE_MM_21
# 42     42     TEM_AVG_MM_28
# 43     43       RAIN_ACC_28
# 44     44        RAIN_MM_28
# 45     45          RH_MM_28
# 46     46  TEMP_RANGE_MM_28

# %%
# Verificando a dimensionalidade dos dados
print("\nDimensionalidade dos dados:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Dimensionalidade dos dados:
# X_train shape: (235118, 47)
# y_train shape: (235118,)

# %% [markdown]
# O dataset é **altamente desbalanceado**, com a maioria das observações registrando **zero casos** de dengue.
# Essa característica é comum em contextos epidemiológicos onde a maioria dos dias/unidades não apresentam surtos.

# %%
# Estatísticas de distribuição de classes
n_total = len(y_train)
n_positive = np.sum(y_train > 0)
n_zero = n_total - n_positive
pct_positive = (n_positive / n_total) * 100

print(f"Total de amostras: {n_total}")
print(f"Com casos (>0): {n_positive} ({pct_positive:.2f}%)")
print(f"Sem casos (=0): {n_zero} ({100 - pct_positive:.2f}%)")
# Out:
# Total de amostras: 235118
# Com casos (>0): 7805 (3.32%)
# Sem casos (=0): 227313 (96.68%)

# %%
# Correlações com variáveis climáticas
cases_related_vars = [
    'CASES_MM_7', 'CASES_ACC_7', 'CASES_MM_14', 'CASES_ACC_14',
    'CASES_MM_21', 'CASES_ACC_21', 'CASES_MM_28', 'CASES_ACC_28',
    'CASES_LAG_1', 'CASES_LAG_2', 'CASES_LAG_3', 'CASES_LAG_4',
    'CASES_LAG_5', 'CASES_LAG_6'
]
climate_vars = [f for f in feature_dict['Feature'] if f not in cases_related_vars]

df_train_climate = pd.DataFrame(X_train, columns=feature_dict['Feature'])
df_train_climate = df_train_climate[climate_vars]
df_train_climate['Casos'] = y_train

corr_matrix_climate = df_train_climate.corr()

plt.figure(figsize=(12, 6))
corr_matrix_climate['Casos'].sort_values(ascending=False)[:-1].plot(kind='bar')
plt.title('Correlação entre Variáveis Climáticas e Casos de Dengue')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Mostrando as 10 variáveis climáticas mais correlacionadas
print("\nTop 10 variáveis CLIMÁTICAS mais correlacionadas com Casos de Dengue:")
print(corr_matrix_climate['Casos'].sort_values(ascending=False).head(11)[1:])  # Pula a correlação consigo mesmo

print("\nTop 10 variáveis CLIMÁTICAS mais negativamente correlacionadas com Casos de Dengue:")
print(corr_matrix_climate['Casos'].sort_values().head(10))
# Out:
# Top 10 variáveis CLIMÁTICAS mais correlacionadas com Casos de Dengue:
# Feature
# RAIN_ACC_21     0.032468
# RAIN_MM_21      0.032468
# RAIN_ACC_28     0.031881
# RAIN_MM_28      0.031881
# RAIN_MM_14      0.027074
# RAIN_ACC_14     0.027074
# RH_MM_7         0.018568
# RH_MM_14        0.016504
# RH_AVG          0.015392
# EXTREME_TEMP    0.014736
# Name: Casos, dtype: float64
#
# Top 10 variáveis CLIMÁTICAS mais negativamente correlacionadas com Casos de Dengue:
# Feature
# WEEK_OF_YEAR       -0.031065
# TEMP_RANGE_MM_7    -0.025737
# TEMP_RANGE_MM_14   -0.023960
# TEMP_RANGE         -0.017104
# TEM_MAX            -0.015629
# TEMP_RANGE_MM_21   -0.014926
# TEM_AVG            -0.003996
# TEMP_RANGE_MM_28   -0.003591
# SIGNIFICANT_RAIN   -0.002144
# TEM_MIN            -0.001036
# Name: Casos, dtype: float64

# %% [markdown]
# ## 3 - Classificação Binária

# %% [markdown]
# ### 3.1 Pré-processamento

# %%
# Transformando y em binário (1 = caso, 0 = sem caso)
y_train_bin = (y_train > 0).astype(int)
y_val_bin = (y_val > 0).astype(int)
y_test_bin = (y_test > 0).astype(int)

# %% [markdown]
# #### Criando janelas temporais

# %%
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(window_size, len(X)):
        X_seq.append(X[i-window_size:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

window_size = 14

X_train_seq, y_train_seq = create_sequences(X_train, y_train_bin, window_size)
X_val_seq, y_val_seq = create_sequences(X_val, y_val_bin, window_size)
X_test_seq, y_test_seq = create_sequences(X_test, y_test_bin, window_size)

# %% [markdown]
# #### Normalização

# %%
X_scaler = MinMaxScaler()

X_train_flat = X_train_seq.reshape(-1, X_train_seq.shape[2])
X_val_flat = X_val_seq.reshape(-1, X_val_seq.shape[2])
X_test_flat = X_test_seq.reshape(-1, X_test_seq.shape[2])

X_scaler.fit(X_train_flat)

X_train_norm = X_scaler.transform(X_train_flat).reshape(X_train_seq.shape)
X_val_norm = X_scaler.transform(X_val_flat).reshape(X_val_seq.shape)
X_test_norm = X_scaler.transform(X_test_flat).reshape(X_test_seq.shape)

# %% [markdown]
# ### 3.2 Modelo LSTM

# %%
lstm_model = Sequential([
    Input(shape=(window_size, X_train_norm.shape[2])),
    LSTM(64, return_sequences=False),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # Saída binária
])

lstm_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# %%
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, verbose=1),
    ModelCheckpoint('melhor_lstm_classificacao.keras', save_best_only=True, monitor='val_loss')
]

# %%
history_lstm = lstm_model.fit(
    X_train_norm, y_train_seq,
    validation_data=(X_val_norm, y_val_seq),
    epochs=100,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - accuracy: 0.9671 - loss: 0.1376 - precision_1: 0.5212 - recall_1: 0.0780 - val_accuracy: 0.9655 - val_loss: 0.1185 - val_precision_1: 0.6715 - val_recall_1: 0.2957 - learning_rate: 0.0010
# Epoch 2/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9725 - loss: 0.0980 - precision_1: 0.7101 - recall_1: 0.2837 - val_accuracy: 0.9674 - val_loss: 0.1101 - val_precision_1: 0.7435 - val_recall_1: 0.3024 - learning_rate: 0.0010
# Epoch 3/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.9732 - loss: 0.0915 - precision_1: 0.7140 - recall_1: 0.3148 - val_accuracy: 0.9677 - val_loss: 0.1088 - val_precision_1: 0.7226 - val_recall_1: 0.3325 - learning_rate: 0.0010
# Epoch 4/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.9735 - loss: 0.0885 - precision_1: 0.7199 - recall_1: 0.3231 - val_accuracy: 0.9680 - val_loss: 0.1096 - val_precision_1: 0.7381 - val_recall_1: 0.3283 - learning_rate: 0.0010
# Epoch 5/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9737 - loss: 0.0869 - precision_1: 0.7238 - recall_1: 0.3290 - val_accuracy: 0.9682 - val_loss: 0.1090 - val_precision_1: 0.7418 - val_recall_1: 0.3332 - learning_rate: 0.0010
# Epoch 6/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9738 - loss: 0.0861 - precision_1: 0.7243 - recall_1: 0.3337 - val_accuracy: 0.9679 - val_loss: 0.1083 - val_precision_1: 0.7691 - val_recall_1: 0.3021 - learning_rate: 0.0010
# Epoch 7/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.9741 - loss: 0.0851 - precision_1: 0.7370 - recall_1: 0.3365 - val_accuracy: 0.9679 - val_loss: 0.1057 - val_precision_1: 0.7839 - val_recall_1: 0.2910 - learning_rate: 0.0010
# Epoch 8/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9739 - loss: 0.0844 - precision_1: 0.7318 - recall_1: 0.3318 - val_accuracy: 0.9677 - val_loss: 0.1055 - val_precision_1: 0.7934 - val_recall_1: 0.2784 - learning_rate: 0.0010
# Epoch 9/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9740 - loss: 0.0835 - precision_1: 0.7280 - recall_1: 0.3404 - val_accuracy: 0.9682 - val_loss: 0.1042 - val_precision_1: 0.7653 - val_recall_1: 0.3128 - learning_rate: 0.0010
# Epoch 10/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9743 - loss: 0.0832 - precision_1: 0.7354 - recall_1: 0.3447 - val_accuracy: 0.9683 - val_loss: 0.1033 - val_precision_1: 0.7519 - val_recall_1: 0.3296 - learning_rate: 0.0010
# Epoch 11/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9743 - loss: 0.0826 - precision_1: 0.7353 - recall_1: 0.3467 - val_accuracy: 0.9683 - val_loss: 0.1017 - val_precision_1: 0.7615 - val_recall_1: 0.3196 - learning_rate: 0.0010
# Epoch 12/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9743 - loss: 0.0821 - precision_1: 0.7339 - recall_1: 0.3477 - val_accuracy: 0.9684 - val_loss: 0.1015 - val_precision_1: 0.7461 - val_recall_1: 0.3361 - learning_rate: 0.0010
# Epoch 13/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9742 - loss: 0.0817 - precision_1: 0.7331 - recall_1: 0.3437 - val_accuracy: 0.9679 - val_loss: 0.1025 - val_precision_1: 0.7727 - val_recall_1: 0.2976 - learning_rate: 0.0010
# Epoch 14/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9746 - loss: 0.0815 - precision_1: 0.7443 - recall_1: 0.3515 - val_accuracy: 0.9680 - val_loss: 0.1025 - val_precision_1: 0.7831 - val_recall_1: 0.2929 - learning_rate: 0.0010
# Epoch 15/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9745 - loss: 0.0809 - precision_1: 0.7419 - recall_1: 0.3494 - val_accuracy: 0.9681 - val_loss: 0.1014 - val_precision_1: 0.7578 - val_recall_1: 0.3157 - learning_rate: 0.0010
# Epoch 16/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9746 - loss: 0.0810 - precision_1: 0.7432 - recall_1: 0.3542 - val_accuracy: 0.9682 - val_loss: 0.1003 - val_precision_1: 0.7561 - val_recall_1: 0.3202 - learning_rate: 0.0010
# Epoch 17/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9745 - loss: 0.0804 - precision_1: 0.7405 - recall_1: 0.3499 - val_accuracy: 0.9681 - val_loss: 0.1015 - val_precision_1: 0.7603 - val_recall_1: 0.3126 - learning_rate: 0.0010
# Epoch 18/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9746 - loss: 0.0801 - precision_1: 0.7470 - recall_1: 0.3490 - val_accuracy: 0.9681 - val_loss: 0.1013 - val_precision_1: 0.7612 - val_recall_1: 0.3137 - learning_rate: 0.0010
# Epoch 19/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9748 - loss: 0.0799 - precision_1: 0.7443 - recall_1: 0.3599 - val_accuracy: 0.9682 - val_loss: 0.1004 - val_precision_1: 0.7454 - val_recall_1: 0.3319 - learning_rate: 0.0010
# Epoch 20/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9748 - loss: 0.0798 - precision_1: 0.7466 - recall_1: 0.3592 - val_accuracy: 0.9681 - val_loss: 0.1012 - val_precision_1: 0.7569 - val_recall_1: 0.3170 - learning_rate: 0.0010
# Epoch 21/100
# 3661/3674 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0797 - precision_1: 0.7487 - recall_1: 0.3577
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9748 - loss: 0.0797 - precision_1: 0.7487 - recall_1: 0.3577 - val_accuracy: 0.9681 - val_loss: 0.1014 - val_precision_1: 0.7432 - val_recall_1: 0.3300 - learning_rate: 0.0010
# Epoch 22/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9749 - loss: 0.0781 - precision_1: 0.7511 - recall_1: 0.3599 - val_accuracy: 0.9683 - val_loss: 0.1015 - val_precision_1: 0.7467 - val_recall_1: 0.3318 - learning_rate: 5.0000e-04
# Epoch 23/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9751 - loss: 0.0772 - precision_1: 0.7476 - recall_1: 0.3712 - val_accuracy: 0.9682 - val_loss: 0.1016 - val_precision_1: 0.7527 - val_recall_1: 0.3251 - learning_rate: 5.0000e-04
# Epoch 24/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9750 - loss: 0.0772 - precision_1: 0.7469 - recall_1: 0.3651 - val_accuracy: 0.9680 - val_loss: 0.1019 - val_precision_1: 0.7645 - val_recall_1: 0.3064 - learning_rate: 5.0000e-04
# Epoch 25/100
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9752 - loss: 0.0773 - precision_1: 0.7599 - recall_1: 0.3656 - val_accuracy: 0.9682 - val_loss: 0.1015 - val_precision_1: 0.7407 - val_recall_1: 0.3351 - learning_rate: 5.0000e-04
# Epoch 26/100
# 3670/3674 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9749 - loss: 0.0771 - precision_1: 0.7430 - recall_1: 0.3655
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3674/3674 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9749 - loss: 0.0771 - precision_1: 0.7430 - recall_1: 0.3655 - val_accuracy: 0.9679 - val_loss: 0.1022 - val_precision_1: 0.7574 - val_recall_1: 0.3089 - learning_rate: 5.0000e-04

# %% [markdown]
# ### 3.3 Avaliação do Modelo

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

y_pred_probs = lstm_model.predict(X_test_norm).flatten()
y_pred_labels = (y_pred_probs >= 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test_seq, y_pred_labels))

cm = confusion_matrix(y_test_seq, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Sem casos', 'Com casos'])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM Classificação")
plt.grid(False)
plt.show()
# Out:
# 2852/2852 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     82271
#            1       0.75      0.36      0.49      8990
#
#     accuracy                           0.93     91261
#    macro avg       0.84      0.68      0.72     91261
# weighted avg       0.92      0.93      0.91     91261

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    roc_curve,
    precision_recall_curve,
    balanced_accuracy_score,
    f1_score
)

# %%
# AUC-ROC
roc_auc = roc_auc_score(y_test_seq, y_pred_probs)

# AUC-PR
pr_auc = average_precision_score(y_test_seq, y_pred_probs)

# Balanced Accuracy
bal_acc = balanced_accuracy_score(y_test_seq, y_pred_labels)

# F1 Score
f1 = f1_score(y_test_seq, y_pred_labels)

print(f"\nMétricas adicionais:")
print(f"AUC-ROC: {roc_auc:.4f}")
print(f"AUC-PR : {pr_auc:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Balanced Accuracy: {bal_acc:.4f}")
# Out:
# Métricas adicionais:
# AUC-ROC: 0.9059
# AUC-PR : 0.6145
# F1 Score: 0.4899
# Balanced Accuracy: 0.6753

# %%
# ROC Curve
fpr, tpr, _ = roc_curve(y_test_seq, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], 'k--', label="Random")
plt.xlabel("FPR (1 - Especificidade)")
plt.ylabel("TPR (Sensibilidade)")
plt.title("Curva ROC")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test_seq, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(recall, precision, label=f"AP = {pr_auc:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Curva Precision-Recall")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Resumo Crítico
#
# - O modelo é conservador: prefere errar por omissão (não prever dengue quando tem) do que por alarme falso.
#
# - Ele é muito bom em evitar falsos positivos, mas perde muitos casos reais, o que pode ser crítico em contexto de saúde pública.
#
# - O AUC-ROC alto indica que o modelo poderia ser calibrado para melhorar o recall, ajustando o threshold de decisão (por padrão é 0.5).

# %% [markdown]
# ## 4 - Regressão

# %% [markdown]
# ### 4.1 LSTM

# %% [markdown]
# Filtrando dados com casos > 0

# %%
# Usando os y originais (regressão), que não são binários
# Filtra apenas as sequências cujo target > 0
mask_train = y_train[window_size:] > 0
mask_val = y_val[window_size:] > 0
mask_test = y_test[window_size:] > 0

X_train_reg = X_train_norm[mask_train]
y_train_raw = y_train[window_size:][mask_train]
y_train_reg = np.log1p(y_train_raw)  # log(1 + y)

X_val_reg = X_val_norm[mask_val]
y_val_raw = y_val[window_size:][mask_val]
y_val_reg = np.log1p(y_val_raw)

X_test_reg = X_test_norm[mask_test]
y_test_raw = y_test[window_size:][mask_test]
y_test_reg = np.log1p(y_test_raw)

# %%
sample_weights = np.where(y_train_raw > 5, 2.0, 1.0)

# %%
from tensorflow.keras.losses import Huber

lstm_reg = Sequential([
    Input(shape=(window_size, X_train_reg.shape[2])),
    LSTM(64, return_sequences=False),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='linear')
])

lstm_reg.compile(
    optimizer='adam',
    loss=Huber(delta=1.0),
    metrics=['mae']
)

callbacks_reg = [
    EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, verbose=1),
    ModelCheckpoint('melhor_lstm_regressao.keras', save_best_only=True, monitor='val_loss')
]

# %%
history_reg = lstm_reg.fit(
    X_train_reg, y_train_reg,
    validation_data=(X_val_reg, y_val_reg),
    sample_weight=sample_weights,
    epochs=100,
    batch_size=64,
    callbacks=callbacks_reg,
    verbose=1
)
# Out:
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.5933 - mae: 0.7460 - val_loss: 0.1766 - val_mae: 0.4744 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3507 - mae: 0.5510 - val_loss: 0.1690 - val_mae: 0.4689 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3099 - mae: 0.5144 - val_loss: 0.1668 - val_mae: 0.4625 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2952 - mae: 0.4980 - val_loss: 0.1562 - val_mae: 0.4019 - learning_rate: 0.0010
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2704 - mae: 0.4709 - val_loss: 0.1474 - val_mae: 0.4154 - learning_rate: 0.0010
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2622 - mae: 0.4652 - val_loss: 0.1447 - val_mae: 0.4050 - learning_rate: 0.0010
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2566 - mae: 0.4560 - val_loss: 0.1389 - val_mae: 0.3850 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2531 - mae: 0.4483 - val_loss: 0.1483 - val_mae: 0.3863 - learning_rate: 0.0010
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2361 - mae: 0.4351 - val_loss: 0.1411 - val_mae: 0.3788 - learning_rate: 0.0010
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2393 - mae: 0.4390 - val_loss: 0.1325 - val_mae: 0.3908 - learning_rate: 0.0010
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2277 - mae: 0.4277 - val_loss: 0.1354 - val_mae: 0.3693 - learning_rate: 0.0010
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2321 - mae: 0.4308 - val_loss: 0.1347 - val_mae: 0.3761 - learning_rate: 0.0010
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2262 - mae: 0.4238 - val_loss: 0.1330 - val_mae: 0.3739 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2222 - mae: 0.4187 - val_loss: 0.1281 - val_mae: 0.3724 - learning_rate: 0.0010
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2207 - mae: 0.4190 - val_loss: 0.1295 - val_mae: 0.3697 - learning_rate: 0.0010
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2169 - mae: 0.4141 - val_loss: 0.1254 - val_mae: 0.3744 - learning_rate: 0.0010
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2183 - mae: 0.4154 - val_loss: 0.1286 - val_mae: 0.3669 - learning_rate: 0.0010
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2147 - mae: 0.4107 - val_loss: 0.1293 - val_mae: 0.3754 - learning_rate: 0.0010
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2082 - mae: 0.4065 - val_loss: 0.1276 - val_mae: 0.3751 - learning_rate: 0.0010
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2064 - mae: 0.4054 - val_loss: 0.1307 - val_mae: 0.3660 - learning_rate: 0.0010
# Epoch 21/100
# 106/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2084 - mae: 0.4057
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2081 - mae: 0.4054 - val_loss: 0.1265 - val_mae: 0.3717 - learning_rate: 0.0010
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2090 - mae: 0.4041 - val_loss: 0.1225 - val_mae: 0.3648 - learning_rate: 5.0000e-04
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2106 - mae: 0.4065 - val_loss: 0.1223 - val_mae: 0.3704 - learning_rate: 5.0000e-04
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2026 - mae: 0.3999 - val_loss: 0.1215 - val_mae: 0.3680 - learning_rate: 5.0000e-04
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2018 - mae: 0.3988 - val_loss: 0.1221 - val_mae: 0.3687 - learning_rate: 5.0000e-04
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2040 - mae: 0.4011 - val_loss: 0.1232 - val_mae: 0.3724 - learning_rate: 5.0000e-04
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2058 - mae: 0.4028 - val_loss: 0.1225 - val_mae: 0.3746 - learning_rate: 5.0000e-04
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2037 - mae: 0.4021 - val_loss: 0.1210 - val_mae: 0.3675 - learning_rate: 5.0000e-04
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2030 - mae: 0.3997 - val_loss: 0.1233 - val_mae: 0.3654 - learning_rate: 5.0000e-04
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1982 - mae: 0.3944 - val_loss: 0.1208 - val_mae: 0.3718 - learning_rate: 5.0000e-04
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2003 - mae: 0.3960 - val_loss: 0.1219 - val_mae: 0.3694 - learning_rate: 5.0000e-04
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2001 - mae: 0.3984 - val_loss: 0.1210 - val_mae: 0.3666 - learning_rate: 5.0000e-04
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2027 - mae: 0.3989 - val_loss: 0.1207 - val_mae: 0.3686 - learning_rate: 5.0000e-04
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1998 - mae: 0.3978 - val_loss: 0.1211 - val_mae: 0.3689 - learning_rate: 5.0000e-04
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1989 - mae: 0.3959 - val_loss: 0.1203 - val_mae: 0.3672 - learning_rate: 5.0000e-04
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1956 - mae: 0.3928 - val_loss: 0.1211 - val_mae: 0.3716 - learning_rate: 5.0000e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1931 - mae: 0.3905 - val_loss: 0.1217 - val_mae: 0.3659 - learning_rate: 5.0000e-04
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1981 - mae: 0.3951 - val_loss: 0.1206 - val_mae: 0.3731 - learning_rate: 5.0000e-04
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1950 - mae: 0.3944 - val_loss: 0.1203 - val_mae: 0.3694 - learning_rate: 5.0000e-04
# Epoch 40/100
# 117/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1939 - mae: 0.3918
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1938 - mae: 0.3918 - val_loss: 0.1211 - val_mae: 0.3721 - learning_rate: 5.0000e-04
# Epoch 41/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1921 - mae: 0.3916 - val_loss: 0.1195 - val_mae: 0.3785 - learning_rate: 2.5000e-04
# Epoch 42/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1927 - mae: 0.3926 - val_loss: 0.1195 - val_mae: 0.3765 - learning_rate: 2.5000e-04
# Epoch 43/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1954 - mae: 0.3933 - val_loss: 0.1216 - val_mae: 0.3823 - learning_rate: 2.5000e-04
# Epoch 44/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1908 - mae: 0.3906 - val_loss: 0.1208 - val_mae: 0.3829 - learning_rate: 2.5000e-04
# Epoch 45/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1927 - mae: 0.3912 - val_loss: 0.1190 - val_mae: 0.3760 - learning_rate: 2.5000e-04
# Epoch 46/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1909 - mae: 0.3897 - val_loss: 0.1214 - val_mae: 0.3831 - learning_rate: 2.5000e-04
# Epoch 47/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1923 - mae: 0.3922 - val_loss: 0.1192 - val_mae: 0.3782 - learning_rate: 2.5000e-04
# Epoch 48/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1899 - mae: 0.3876 - val_loss: 0.1205 - val_mae: 0.3779 - learning_rate: 2.5000e-04
# Epoch 49/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1898 - mae: 0.3882 - val_loss: 0.1203 - val_mae: 0.3772 - learning_rate: 2.5000e-04
# Epoch 50/100
# 113/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1904 - mae: 0.3887
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1900 - mae: 0.3883 - val_loss: 0.1200 - val_mae: 0.3793 - learning_rate: 2.5000e-04
# Epoch 51/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1865 - mae: 0.3861 - val_loss: 0.1177 - val_mae: 0.3658 - learning_rate: 1.2500e-04
# Epoch 52/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1893 - mae: 0.3848 - val_loss: 0.1180 - val_mae: 0.3666 - learning_rate: 1.2500e-04
# Epoch 53/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1873 - mae: 0.3844 - val_loss: 0.1187 - val_mae: 0.3693 - learning_rate: 1.2500e-04
# Epoch 54/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1849 - mae: 0.3793 - val_loss: 0.1181 - val_mae: 0.3655 - learning_rate: 1.2500e-04
# Epoch 55/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1860 - mae: 0.3830 - val_loss: 0.1182 - val_mae: 0.3675 - learning_rate: 1.2500e-04
# Epoch 56/100
# 115/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1897 - mae: 0.3855
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1895 - mae: 0.3854 - val_loss: 0.1186 - val_mae: 0.3662 - learning_rate: 1.2500e-04
# Epoch 57/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1883 - mae: 0.3834 - val_loss: 0.1181 - val_mae: 0.3680 - learning_rate: 6.2500e-05
# Epoch 58/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1844 - mae: 0.3803 - val_loss: 0.1185 - val_mae: 0.3691 - learning_rate: 6.2500e-05
# Epoch 59/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1881 - mae: 0.3845 - val_loss: 0.1179 - val_mae: 0.3666 - learning_rate: 6.2500e-05
# Epoch 60/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1847 - mae: 0.3807 - val_loss: 0.1184 - val_mae: 0.3691 - learning_rate: 6.2500e-05
# Epoch 61/100
# 116/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1829 - mae: 0.3814
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1829 - mae: 0.3814 - val_loss: 0.1187 - val_mae: 0.3703 - learning_rate: 6.2500e-05

# %%
y_pred_log = lstm_reg.predict(X_test_reg).flatten()
y_pred = np.expm1(y_pred_log)  # desfaz log1p
y_test_true = np.expm1(y_test_reg)  # desfaz log1p
# Out:
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

# Métricas
mae = mean_absolute_error(y_test_true, y_pred)
rmse = root_mean_squared_error(y_test_true, y_pred) 
r2 = r2_score(y_test_true, y_pred)

print(f"MAE:  {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²:   {r2:.4f}")
# Out:
# MAE:  1.76
# RMSE: 4.28
# R²:   0.5907

# %%
plt.figure(figsize=(6, 6))
plt.scatter(y_test_true, y_pred, alpha=0.5, color='teal')
plt.plot([y_test_true.min(), y_test_true.max()],
         [y_test_true.min(), y_test_true.max()], 'r--', lw=2)
plt.xscale('log')  # Escala logarítmica no eixo X
plt.yscale('log')  # Escala logarítmica no eixo Y
plt.xlabel("Casos Reais (log)")
plt.ylabel("Casos Previstos (log)")
plt.title("Dispersão - Escala Logarítmica", fontsize=13)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
residuals = y_test_true - y_pred
plt.figure(figsize=(6, 4))
plt.scatter(y_pred, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Casos Previstos")
plt.ylabel("Resíduo (Real - Previsto)")
plt.title("Resíduos vs Previsões")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
